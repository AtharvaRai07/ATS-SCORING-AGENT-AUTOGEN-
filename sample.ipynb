# %%
from dotenv import load_dotenv
import os 

load_dotenv()

DB_NAME = os.getenv("dbname")
USER = os.getenv("user")
PASSWORD = os.getenv("password")
HOST = os.getenv("host")
PORT = os.getenv("port")
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
print(HOST)
# Out:
# aws-0-ap-south-1.pooler.supabase.com

# %%
import json
import os
import psycopg2
from dotenv import load_dotenv

load_dotenv()

DB_NAME = os.getenv("dbname")
USER = os.getenv("user")
PASSWORD = os.getenv("password")
HOST = os.getenv("host")
PORT = os.getenv("port")

def connect_to_superbase(db_name,user,password,host,port):
    connection = None
    try:
        connection = psycopg2.connect(
            database = db_name,
            user = user,
            password = password,
            host = host,
            port = port 
        )
        print(f"Connect to postgress DB({db_name}) is succesful.")
        return connection
    except Exception as e:
        print(f"Error occured while creating connection to DB: {db_name}, Error: {str(e)}")
        return connection

conn_online_db = connect_to_superbase(DB_NAME,USER,PASSWORD,HOST,PORT)

def execute_query(connection,query,params=None):
    try:
        cursor = connection.cursor()
        cursor.execute(query,params)
        if query.strip().upper().startswith(('CREATE','INSERT','UPDATE','DELETE')):
            connection.commit()
            if "RETURNING" in query.upper():
                result = cursor.fetchone()[0]
            else:
                result = cursor.rowcount
            return result
        else:
            print("Query Executed")
            return cursor.fetchall()
    except Exception as e:
        print(f"{str(e)}")
        if connection:
            connection.rollback()
        return None
    finally:
        if cursor:
            cursor.close()
# Out:
# Connect to postgress DB(postgres) is succesful.

# %%
# Create the resumes table
create_resumes_table = """
CREATE TABLE IF NOT EXISTS resumes (
    id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
    original_filename TEXT,
    file_type TEXT,
    raw_text TEXT,
    parsed_json JSONB,
    uploaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);
"""

# Create the job_descriptions table
create_jd_table = """
CREATE TABLE IF NOT EXISTS job_descriptions (
    id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
    resume_id UUID REFERENCES resumes(id) ON DELETE CASCADE,
    original_filename TEXT,
    raw_text TEXT,
    parsed_json JSONB,
    uploaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);
"""

# Create the scores table
create_scores_table = """
CREATE TABLE IF NOT EXISTS scores (
    score_id UUID PRIMARY KEY DEFAULT gen_random_uuid(),
    resume_id UUID REFERENCES resumes(id) ON DELETE CASCADE,
    score_breakdown JSONB,
    total_score FLOAT,
    recommendations JSONB,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);
"""

if conn_online_db:
    execute_query(conn_online_db, "CREATE EXTENSION IF NOT EXISTS pgcrypto;")
    execute_query(conn_online_db, create_resumes_table)
    execute_query(conn_online_db, create_jd_table)
    execute_query(conn_online_db, create_scores_table)

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.ui import Console
from autogen_agentchat.base import TaskResult
import os
from dotenv import load_dotenv
load_dotenv()

api_key = os.getenv('GROQ_API_KEY')

model_client = OpenAIChatCompletionClient(
    base_url="https://api.groq.com/openai/v1", 
    model="openai/gpt-oss-120b", 
    api_key=api_key, 
    model_info={
        "family": "groq",
        "vision": False, 
        "function_calling": True,
        "json_output": False
    }
) 

sample_agent = AssistantAgent(
    name="sample_agent",
    model_client=model_client,
    system_message="You are a helpful assistant."
)

result = await sample_agent.run(task=(TextMessage(content="Hello how are you",source="user")))
print(result.messages[-1].content)
# Out:
# c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:453: UserWarning: Missing required field 'structured_output' in ModelInfo. This field will be required in a future version of AutoGen.
#   validate_model_info(self._model_info)
# Hello! I'm doing well, thank you for asking. How can I assist you today?

# %%
import pdfplumber
import docx
import mimetypes


def extract_text_from_file(file_path:str)->str:
    """Extract text from PDF, DOCX, or TXT file without textract."""
    file_type,_ = mimetypes.guess_type(file_path)

    if file_type =='application/pdf':
        with pdfplumber.open(file_path) as pdf:
            text = "\n".join([page.extract_text() for page in pdf.pages])
    elif file_type == "application/vnd.openxmlformats-officedocument.wordprocessingml.document":
        doc_file = docx.Document(file_path)
        text = "\n".join([para.text for para in doc_file.paragraphs])
    elif file_type == "text/plain":
        with open(file_path,"r",encoding="utf-8") as f:
            text = f.read()
    else:
        raise ValueError(f"Unsupported file type: {file_type}")
    
    return file_type,text.strip()

# %%
from optparse import Option
from pydantic import BaseModel,Field
from typing import List,Dict,Optional

class ResumeParser(BaseModel):
    """Parse key resume fields from text"""

    file_type : Optional[str] = Field(None,description="File type of the resume.")

    name : Optional[str] = Field(None,description="Full name of the candidate.")

    contact : Optional[Dict[str,Optional[str]]] = Field(
        None,
        description="Contact information with email and phone."
    )
    skills : List[str] = Field(
        default_factory=list,
        description="List of skills mentioned in the resume.",
    )
    experience : List[str] = Field(
        default_factory=list,
        description="List of work experience mentioned in the resume.",
    )
    education : List[str] = Field(
        default_factory=list,
        description="List of education mentioned in the resume.",
    )
    certifications : List[str] = Field(
        default_factory=list,
        description="List of certifications mentioned in the resume.",
    )

# %%
extracted_text = extract_text_from_file("resume.txt")
print(extracted_text)
# Out:
# ('text/plain', 'John Doe\nEmail: john.doe@example.com\nPhone: +1 987 654 3210\n\nProfessional Summary:\nHighly motivated software engineer with 4 years of experience in backend and cloud technologies.\n\nSkills:\nPython, SQL, Java, Machine Learning, AWS, Docker, Kubernetes\n\nExperience:\nSoftware Engineer - ABC Tech (2018 - 2020)\nSenior Software Engineer - XYZ Solutions (2020 - Present)\n\nEducation:\nB.Tech Computer Science - University of Example (2014 - 2018)\n\nCertifications:\nAWS Certified Developer')

# %%
openai_api_key = os.getenv('OPENAI_API_KEY')
json_model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=openai_api_key,
    response_format=ResumeParser                                                                                           
)
extracted_text_json = AssistantAgent(
    name="json_extractor",
    model_client= json_model_client,
    system_message="""You are a resume parser agent when you are given a resume text, you will extract the information from the resume and return it in a json format. In the extracted text there is also file_type written as starting""")

# %%
result = await extracted_text_json.run(task=(TextMessage(content=f"Extract text from the resume\n\n\n {extracted_text}",source="user")))
print(result.messages[-1].content)
# Out:
# {"file_type":"text/plain","name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}

# %%
content = result.messages[-1].content

# %%
import json
parsed_data = json.loads(content)
print(parsed_data)
parsed_data['file_type']
# Out:
# {'file_type': 'text/plain', 'name': 'John Doe', 'contact': {'email': 'john.doe@example.com', 'phone': '+1 987 654 3210'}, 'skills': ['Python', 'SQL', 'Java', 'Machine Learning', 'AWS', 'Docker', 'Kubernetes'], 'experience': ['Software Engineer - ABC Tech (2018 - 2020)', 'Senior Software Engineer - XYZ Solutions (2020 - Present)'], 'education': ['B.Tech Computer Science - University of Example (2014 - 2018)'], 'certifications': ['AWS Certified Developer']}
# 'text/plain'

# %%
ids = []
def save_resume_to_db(conn,parsed_string):
    query = """
    INSERT INTO resumes (file_type, raw_text, parsed_json)
    VALUES (%s, %s, %s)
    RETURNING id;
    """
    params = (
        parsed_string['file_type'],
        extracted_text,
        json.dumps(parsed_string),
    )
    try:
        if conn_online_db:
            resume_id = execute_query(conn, query, params)
            ids.append(resume_id)
            return f"Resume saved to database successfully and id is {resume_id}"
        else:
            raise Exception("Connection to online database is not established")
    except Exception as e:
        raise Exception(f"Failed to save resume to database: {str(e)}")

# %%
save_resume_to_db(conn_online_db,parsed_data)
# Out:
# 'Resume saved to database successfully'

# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()

JSEARCH_API = os.getenv('JSEARCH_API_KEY')

def JSearchAPI(query:str):
    """The tool searches for job based on the query"""
    url = "https://jsearch.p.rapidapi.com/search"
    headers = {
    'x-rapidapi-key':JSEARCH_API,
    'x-rapidapi-host': "jsearch.p.rapidapi.com"
    }

    params = {
        "query":query,
        "country":"in",
        "num_pages":1,
        "page":1,
    }

    response = requests.get(url,headers=headers,params=params)
    data = response.json()

    jobs = []
    for job in data.get("data", [])[:5]:
        jobs.append({
            "role": job.get("job_title"),
            "company": job.get("employer_name"),
            "employment_type": job.get("job_employment_type"),
            "job_location": job.get("job_location"),
            "job_salary": f"{job.get('job_min_salary')} - {job.get('job_max_salary')} {job.get('job_salary_period') or ''}".strip(),
            "job_description": job.get("job_description", ""),
            "job_apply_link": job.get("job_apply_link", "")
        })
    return jobs

jobs = JSearchAPI("python developer")
print(jobs)
# Out:
# [{'role': 'Lead Software Engineer - Python', 'company': 'EPAM Systems', 'employment_type': 'Full–time', 'job_location': 'India', 'job_salary': 'None - None', 'job_description': 'We are seeking a highly experienced Lead Software Engineer with expertise in Python to lead development efforts, influence technical direction, and deliver robust, scalable solutions.\n\nThe ideal candidate will bring proven expertise in Python, database systems, and modern software development practices to drive the success of critical projects.\n\nResponsibilities\n• Collaborate with stakeholders to gather requirements, create technical designs, and align solutions with business goals\n• Lead the development of high-quality, scalable, and maintainable software systems\n• Conduct technical reviews, including code reviews, to ensure adherence to best practices, coding standards, and performance benchmarks\n• Coordinate with cross-functional teams to ensure successful implementation of features and solutions\n• Troubleshoot and resolve complex technical challenges across the development lifecycle\n• Mentor and guide team members, offering technical leadership and fostering skills development\n• Drive the adoption of modern development processes and tools, including CI/CD practices through GitHub Actions\n• Optimize application performance and database queries, ensuring efficiency and scalability\n• Utilize Agile/Scrum methodologies to manage projects and deliver iterative improvements\n• Oversee database architecture design and ensure proper integration with applications\n\nRequirements\n• 7-12 years of experience in software development with demonstrated expertise in Python\n• Proficiency in PostgreSQL and MS SQL Server for database design, optimization, and management\n• Hands-on expertise with GitHub Actions for automation and CI/CD workflows\n• Competency in ReactJS for developing interactive, dynamic user interfaces\n• Solid understanding of Scrum/Agile methodologies for collaborative development and delivery\n\nNice to have\n• Familiarity with other front-end frameworks beyond ReactJS\n• Skills in optimizing cross-platform application performance\n• Understanding of advanced DevOps practices and tools', 'job_apply_link': 'https://in.linkedin.com/jobs/view/lead-software-engineer-python-at-epam-systems-4282811031?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}, {'role': 'Python Developer / Data Analyst - +3 years of experience - Full remote - Contractor in USD', 'company': 'All European Careers', 'employment_type': 'Contractor', 'job_location': 'India', 'job_salary': 'None - None', 'job_description': 'For an international project in Chennai, we are urgently looking for a Full Remote Data Analyst. The ideal candidate will have good understanding of Data integration, Data cleanup for Knowledge 360 and other related products for knowledge system..\n\nWe are looking for a motivated contractor. Candidates need to be fluent in English.\n\nTasks and responsibilities:\n\nDesign and implement cloud-based solutions using Azure and Google Cloud platforms. Automate data pipelines to facilitate efficient data flow and processing;\n\nDevelop and manage data pipelines using technologies like PySpark and Databricks;\n\nEnsure the scalability and reliability of data processing workflows;\n\nWork with Large Language Models (LLMs) such as GPT and OpenAI models to enhance applications with natural language processing (NLP) capabilities;\n\nDesign and implement prompt engineering strategies to optimize model performance in business applications;\n\nTrain, fine-tune, and deploy AI models, analyzing their performance based on real-world results;\n\nOptimize models using feedback mechanisms to improve efficiency;\n\nUtilize strong communication skills to convey complex technical concepts to non-technical stakeholders;\n\nProfile:\n• Bachelor or Master degree;\n• +3 years of hands-on experience in Python, Pyspark, Databricks, and cloud platf ...

# %%
from autogen_core.tools import FunctionTool
JobFinder = FunctionTool(func=JSearchAPI,name="JobFinder",description="The tool searches for job based on the query")

# %%
def save_jobs_to_db(jobs,conn,resume_id):
    query = """
    INSERT INTO job_descriptions (resume_id, original_filename,parsed_json)
    VALUES (%s,%s,%s)
    RETURNING id;
    """
    try:
        if conn:
            params = (
                resume_id,
                "API_SEARCH",
                json.dumps(jobs)
                )
            execute_query(conn,query,params)
            return "Job saved to DB"
        else:
            raise Exception("Connection not established")
    except Exception as e:
        return str(e)

# %%
resume_id = ids[-1]
print(resume_id)
# Out:
# 2b00559f-245c-4a8d-b90e-be5103499e55

# %%
from typing import Optional, List, Literal
from pydantic import BaseModel, Field

class JobDescriptionData(BaseModel):
    """Schema for a single job description entry."""
    
    role: str = Field(..., description="Job title or position name.")
    
    required_skills: List[str] = Field(
        default_factory=list,
        description="List of essential skills required for this role."
    )
    
    required_experience: Optional[str] = Field(
        None,
        description="Experience required for this role (e.g., '3+ years in Python development')."
    )
    
    required_education: Optional[str] = Field(
        None,
        description="Minimum education requirement for the role."
    )
    
    keywords: List[str] = Field(
        default_factory=list,
        description="Important keywords extracted from the job description."
    )
    
    description_text: Optional[str] = Field(
        None,
        description="Full textual job description."
    )
    
    job_employment_type: Optional[
        Literal["Full-time", "Part-time", "Contract", "Internship", "Remote", "Hybrid", "Onsite"]
    ] = Field(
        None,
        description="Employment type for this role."
    )
    
    job_country: Optional[str] = Field(
        None,
        description="Country where the job is located."
    )

    job_apply_link : Optional[str] = Field(
        None,
        description="Link to apply for the job."
    )

class JobDescriptionList(BaseModel):
    """Schema for a collection of job descriptions."""
    
    jobs: List[JobDescriptionData] = Field(
        default_factory=list,
        description="List of job descriptions the candidate can apply for."
    )

# %%
job_model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=openai_api_key,
    response_format= JobDescriptionList
)

# %%
job_description_agent = AssistantAgent(
    name="Job_Description_Agent",
    model_client= model_client,
    system_message="""
    You are a job description agent. You have been provided a tool name JobFinder where you can query job based on the user parsed resume and give him top 5 jobs for him make sure you follow the the given format and give the answer in json format only 
    When using the tool just write query in 2 words like "python developer" or "Machine Developer" not more than that. 
    In the api call result you wil get apply link make sure to add this.
    """,
    tools=[JobFinder],
    reflect_on_tool_use=True
)

# %%
job_desc_result = await Console(job_description_agent.run_stream(task=TextMessage(content=f"This is the parsed resume of the candidate\n\n\n {content}",source="user")))
result_2 = job_desc_result.messages[-1].content
# Out:
# ---------- TextMessage (user) ----------
# This is the parsed resume of the candidate
#
#
#  {"file_type":"text/plain","name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}
# ---------- ToolCallRequestEvent (Job_Description_Agent) ----------
# [FunctionCall(id='fc_9dd1ee52-16af-4efa-b478-657db9201a48', arguments='{"query":"Machine Learning"}', name='JobFinder')]
# ---------- ToolCallExecutionEvent (Job_Description_Agent) ----------
# [FunctionExecutionResult(content='[{\'role\': \'Machine Learning Engineer – ML Ops & Support\', \'company\': \'Aera Technology\', \'employment_type\': \'Full–time\', \'job_location\': \'Pune, Maharashtra\', \'job_salary\': \'None - None\', \'job_description\': "Aera Technology is the Decision Intelligence company. Our platform, Aera Decision Cloud™, integrates with enterprise systems to digitize, augment, and automate decisions in real time. We deliver millions of AI-powered recommendations each year, generating significant value for some of the world’s largest brands.\\n\\nWe are seeking a Machine Learning Engineer (Support & Ops focus) to ensure our AI-powered decision systems run reliably at scale. This role is less about building models from scratch, and more about keeping production AI systems healthy, observable, and performant, while enabling Data Science teams to deliver faster.\\n\\nThis position is also a strong career pathway into ML feature development — you will work closely with Product, Data Science, and Engineering teams, gain exposure to LLMs, Agentic AI, and advanced ML tooling, and progressively take on more responsibilities in building new ML-powered product features.\\n\\nResponsibilities\\n• Monitor, troubleshoot, and maintain ML pipelines and services in production, ensuring high availability and minimal downtime.\\n• Work closely with Data Scientists and Engineers to operationalize ML/LLM models, from development through deployment.\\n• Build and maintain observability tools for tracking data quality, model performance, drift detection, and inference metrics.\\n• Support LLM and Agentic AI features in production, focusing on stability, optimization, and seamless integration into the platform.\\n• Develop and enhance internal ML tooling for faster experimentation, deployment, and feature integration.\\n• Collaborate with Product teams to roll out new ML-driven features and improve existing ones.\\n• Work with DevOps to improve CI/CD workflows for ML code, data pipelines, and models.\\n• Optimize resource usage and costs for large-scale model hosting and inference.\\n• Document workflows, troubleshooting guides, and best practices for ML systems support.\\n\\nAbout You\\n• B.E./ B.Tech in Computer Science, Engineering, or related field.3–5 years of experience in software engineering, ML Ops, or ML platform support.\\n• Strong Python skills, with experience in production-grade code and automation. Experience with ML pipeline orchestration tools (Airflow, Prefect, Kubeflow, or similar).\\n• Familiarity with containerized microservices (Docker, Kubernetes) and CI/CD pipelines.\\n• Experience monitoring ML systems using tools like Prometheus, Grafana, ELK, Sentry, or equivalent.\\n• Understanding of model packaging and serving frameworks (FastAPI, TorchServe, Triton Inference Server, Hugging Face Inference API).\\n• Strong collaboration skills with cross-functional teams.\\n\\nGood to Have\\n• Exposure to LLM operations (prompt engineering, fine-tuning, inference optimization).Familiarity with Agentic AI workflows and multi-step orchestration (LangChain, LlamaIndex).\\n• Experience with data versioning (DVC, Delta Lake) and experiment tracking (MLflow, Weights & Biases).\\n• Knowledge of vector databases (Pinecone, Weaviate, FAISS).\\n• Experience with streaming data (Kafka) and caching (Redis).\\n• Skills in cost optimization for GPU workloads.\\n• Basic understanding of system design for large-scale AI infrastructure.\\n\\nIf you share our passion for building a sustainable, intelligent, and efficient world, you’re in the right place. Established in 2017 and headquartered in Mountain View, California, we\'re a series D start-up, with teams in Mountain View, San Francisco (California), Bucharest and Cluj-Napoca (Romania), Paris (France), Munich (Germany), London (UK), Pune (India), and Sydney (Australia). So join us, and let’s build this!\\n\\nAera Technology is an equal opportunity employer. Qualified appli ...
# ---------- TextMessage (Job_Description_Agent) ----------
# {
#   "jobs": [
#     {
#       "role": "Machine Learning Engineer – ML Ops & Support",
#       "company": "Aera Technology",
#       "location": "Pune, Maharashtra",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)",
#       "company": "vueverse.",
#       "location": "Guwahati, Assam",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.",
#       "job_apply_link": "https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "Data Scientist (Python and AI/ML)",
#       "company": "EXL",
#       "location": "Noida, Uttar Pradesh",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "Business and Marketing Data Scientist, GTech Ads",
#       "company": "Google",
#       "location": "Mumbai, Maharashtra",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.",
#       "job_apply_link": "https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "Machine Learning Engineer, AVP",
#       "company": "NatWest Digital X",
#       "location": "Bengaluru, Karnataka",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.",
#       "job_apply_link": "https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     }
#   ]
# }

# %%
result_2 = json.loads(result_2)
result_2
# Out:
# {'jobs': [{'role': 'Machine Learning Engineer – ML Ops & Support',
#    'company': 'Aera Technology',
#    'location': 'Pune, Maharashtra',
#    'employment_type': 'Full‑time',
#    'salary': 'Not disclosed',
#    'job_description': 'Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.',
#    'job_apply_link': 'https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'role': 'AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)',
#    'company': 'vueverse.',
#    'location': 'Guwahati, Assam',
#    'employment_type': 'Full‑time',
#    'salary': 'Not disclosed',
#    'job_description': 'Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.',
#    'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'role': 'Data Scientist (Python and AI/ML)',
#    'company': 'EXL',
#    'location': 'Noida, Uttar Pradesh',
#    'employment_type': 'Full‑time',
#    'salary': 'Not disclosed',
#    'job_description': 'Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.',
#    'job_apply_link': 'https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'role': 'Business and Marketing Data Scientist, GTech Ads',
#    'company': 'Google',
#    'location': 'Mumbai, Maharashtra',
#    'employment_type': 'Full‑time',
#    'salary': 'Not disclosed',
#    'job_description': 'Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.',
#    'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'},
#   {'role': 'Machine Learning Engineer, AVP',
#    'company': 'NatWest Digital X',
#    'location': 'Bengaluru, Karnataka',
#    'employment_type': 'Full‑time',
#    'salary': 'Not disclosed',
#    'job_description': 'Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.',
#    'job_apply_link': 'https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic'}]}

# %%
save_jobs_to_db(result_2,conn_online_db,resume_id)
# Out:
# 'Job saved to DB'

# %%
def bring_jobs_data_from_db(conn,resume_id):
    query = """
    SELECT parsed_json FROM job_descriptions WHERE resume_id = %s;
    """
    try:
        if conn:
            params = (
                resume_id,
            )
            result_brought = execute_query(conn_online_db,query,params)
            return result_brought
        else:
            raise Exception("Connection not established")
    except Exception as e:
        return str(e)

# %%
result_3 = bring_jobs_data_from_db(conn_online_db,resume_id)
for i in result_3:
    print(i)
# Out:
# Query Executed
# ({'jobs': [{'role': 'Machine Learning Engineer – ML Ops & Support', 'salary': 'Not disclosed', 'company': 'Aera Technology', 'location': 'Pune, Maharashtra', 'job_apply_link': 'https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.'}, {'role': 'AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)', 'salary': 'Not disclosed', 'company': 'vueverse.', 'location': 'Guwahati, Assam', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.'}, {'role': 'Data Scientist (Python and AI/ML)', 'salary': 'Not disclosed', 'company': 'EXL', 'location': 'Noida, Uttar Pradesh', 'job_apply_link': 'https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.'}, {'role': 'Business and Marketing Data Scientist, GTech Ads', 'salary': 'Not disclosed', 'company': 'Google', 'location': 'Mumbai, Maharashtra', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.'}, {'role': 'Machine Learning Engineer, AVP', 'salary': 'Not disclosed', 'company': 'NatWest Digital X', 'location': 'Bengaluru, Karnataka', 'job_apply_link': 'https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.'}]},)

# %%
model_client = OpenAIChatCompletionClient(
    base_url="https://api.groq.com/openai/v1", 
    model="openai/gpt-oss-20b", 
    api_key=api_key, 
    model_info={
        "family": "groq",
        "vision": False, 
        "function_calling": True,
        "json_output": False
    }
)

# %%
avaible_job_agent = AssistantAgent(
    name="avaible_job",
    model_client= model_client,
    system_message= """You are a available job agent which get data about jobs the user can do based on his/her resume in json format. You have to show the data beutifully to the user in a detailed way point wise. Dont give any "## ✅ How to Proceed" or "**Tip:** like paragraph just the jobs data."""
)

availeb_job_result = await Console(avaible_job_agent.run_stream(task=TextMessage(content=f"This are the avaible job for user based on its resume\n\n\n {result_3}",source="user")))
result_4 = availeb_job_result.messages[-1].content
# Out:
# ---------- TextMessage (user) ----------
# This are the avaible job for user based on its resume
#
#
#  [({'jobs': [{'role': 'Machine Learning Engineer – ML Ops & Support', 'salary': 'Not disclosed', 'company': 'Aera Technology', 'location': 'Pune, Maharashtra', 'job_apply_link': 'https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.'}, {'role': 'AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)', 'salary': 'Not disclosed', 'company': 'vueverse.', 'location': 'Guwahati, Assam', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.'}, {'role': 'Data Scientist (Python and AI/ML)', 'salary': 'Not disclosed', 'company': 'EXL', 'location': 'Noida, Uttar Pradesh', 'job_apply_link': 'https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.'}, {'role': 'Business and Marketing Data Scientist, GTech Ads', 'salary': 'Not disclosed', 'company': 'Google', 'location': 'Mumbai, Maharashtra', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.'}, {'role': 'Machine Learning Engineer, AVP', 'salary': 'Not disclosed', 'company': 'NatWest Digital X', 'location': 'Bengaluru, Karnataka', 'job_apply_link': 'https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.'}]},)]
# ---------- TextMessage (avaible_job) ----------
# **Machine Learning Engineer – ML Ops & Support**
# - **Company:** Aera Technology – Pune, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Key responsibilities:**
#   - Monitor and maintain ML pipelines and services.
#   - Build observability tools and support LLM/Agentic AI features.
#   - Develop internal ML tooling and collaborate with cross‑functional teams.
# - **Required skills:** 3‑5 yrs of software engineering/ML Ops, Python, Docker, Kubernetes, CI/CD, Prometheus/Grafana, AWS.
#
# ---
#
# **AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)**
# - **Company:** vueverse. – Guwahati, Assam
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core focus:** Design & deploy scalable AI/ML & GenAI solutions on cloud for BFSI.
# - **Key skills:** AWS, cloud‑native AI services, MLOps pipelines, LLM tooling (LangChain, Hugging Face).
#
# ---
#
# **Data Scientist (Python and AI/ML)**
# - **Company:** EXL – Noida, Uttar Pradesh
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Role highlights:**
#   - Design, implement, and deploy ML models.
#   - Build pipelines and APIs.
#   - Work with deep learning frameworks.
#
# ---
#
# **Business and Marketing Data Scientist, GTech Ads**
# - **Company:** Google – Mumbai, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Focus area:** Marketing analytics with Python, SQL, ML/AI.
#
# ---
#
# **Machine Learning Engineer, AVP**
# - **Company:** NatWest Digital X – Bengaluru, Karnataka
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core responsibilities:**
#   - Deploy, automate, and monitor ML models at scale.
#   - Use Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, MLOps.
#
# ---

# %%
ats_model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key=openai_api_key,
)

# %%
ats_scoring_agent = AssistantAgent(
    name="ATS_Scoring_Agent",
    model_client= model_client,
    system_message = """
You are an ATS (Applicant Tracking System) Scoring Agent.

Task:
- Given a parsed resume (JSON) and a list of multiple parsed job descriptions (JSON), calculate ONE overall ATS score representing the candidate’s average fit across all provided roles.

Scoring Method:
1. Compare the resume to each job description using the following categories:
   - Skills Match: 30%
   - Experience Relevance: 25%
   - Education Alignment: 15%
   - Format & Structure: 15%
   - Keyword Optimization: 15%
2. For each category, average the category scores across all jobs.
3. Apply the category weights to the averaged category scores to compute a final weighted total score.
4. This must produce a single overall ATS score for all jobs combined.

Consistency Rules:
- The same resume and job descriptions should always produce the same score (deterministic).
- No randomness or subjective guessing.
- If a category is missing data (e.g., job has no education requirement), base the score only on available information and note it in reasoning.

Benchmark Comparison:
- 85–100: Excellent fit
- 70–84: Good fit
- 50–69: Average fit
- Below 50: Poor fit

Confidence Intervals:
- Confidence is lower if job descriptions vary greatly or have missing details.
- Provide ± percentage confidence interval.

Output:
Return only valid JSON:

{
  "total_score": <integer>,
  "category_scores": {
    "skills_match": <integer>,
    "experience_relevance": <integer>,
    "education_alignment": <integer>,
    "format_structure": <integer>,
    "keyword_optimization": <integer>
  },
  "weighted_breakdown": {
    "skills_match_weighted": <float>,
    "experience_relevance_weighted": <float>,
    "education_alignment_weighted": <float>,
    "format_structure_weighted": <float>,
    "keyword_optimization_weighted": <float>
  },
  "benchmark_comparison": "<string>",
  "confidence_interval": "+/-<integer>%",
  "reasoning": {
    "skills_match": "<explanation>",
    "experience_relevance": "<explanation>",
    "education_alignment": "<explanation>",
    "format_structure": "<explanation>",
    "keyword_optimization": "<explanation>"
  }
}

Guidelines:
- Only use the provided resume and job descriptions.
- Average scores across jobs first, then apply weights.
- The sum of weighted scores must equal the total_score.
- Dont write this ```json just json brackets only "{}"
"""

)

# %%
ats_score = await Console(ats_scoring_agent.run_stream(task=TextMessage(content=f"This is parsed resume of the candidate\n\n\n {content} and the sutiable jobs finded using agent\n\n\n {result_3}",source="user")))
ast_result = ats_score.messages[-1].content
# Out:
# ---------- TextMessage (user) ----------
# This is parsed resume of the candidate
#
#
#  {"file_type":"text/plain","name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]} and the sutiable jobs finded using agent
#
#
#  [({'jobs': [{'role': 'Machine Learning Engineer – ML Ops & Support', 'salary': 'Not disclosed', 'company': 'Aera Technology', 'location': 'Pune, Maharashtra', 'job_apply_link': 'https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.'}, {'role': 'AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)', 'salary': 'Not disclosed', 'company': 'vueverse.', 'location': 'Guwahati, Assam', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.'}, {'role': 'Data Scientist (Python and AI/ML)', 'salary': 'Not disclosed', 'company': 'EXL', 'location': 'Noida, Uttar Pradesh', 'job_apply_link': 'https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.'}, {'role': 'Business and Marketing Data Scientist, GTech Ads', 'salary': 'Not disclosed', 'company': 'Google', 'location': 'Mumbai, Maharashtra', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.'}, {'role': 'Machine Learning Engineer, AVP', 'salary': 'Not disclosed', 'company': 'NatWest Digital X', 'location': 'Bengaluru, Karnataka', 'job_apply_link': 'https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.'}]},)]
# ---------- TextMessage (ATS_Scoring_Agent) ----------
# {
#   "total_score": 80,
#   "category_scores": {
#     "skills_match": 63,
#     "experience_relevance": 82,
#     "education_alignment": 100,
#     "format_structure": 90,
#     "keyword_optimization": 70
#   },
#   "weighted_breakdown": {
#     "skills_match_weighted": 19,
#     "experience_relevance_weighted": 21,
#     "education_alignment_weighted": 15,
#     "format_structure_weighted": 14,
#     "keyword_optimization_weighted": 11
#   },
#   "benchmark_comparison": "Good fit",
#   "confidence_interval": "+/-5%",
#   "reasoning": {
#     "skills_match": "The candidate’s skill set matches 63% of the key technical requirements across the five job listings, based on the presence of Python, Docker, Kubernetes, AWS, and general machine‑learning terminology.",
#     "experience_relevance": "With over five years of senior software engineering experience in roles that involve ML and cloud services, the candidate’s experience aligns highly (average 82%) with the experience expectations of the positions.",
#     "education_alignment": "The candidate holds a B.Tech in Computer Science, which satisfies or exceeds the typical bachelor’s‑level requirement present (or implied) in all five listings; hence 100% alignment.",
#     "format_structure": "The parsed resume shows a clean, organized structure with distinct sections (contact, skills, experience, education, certifications), meeting typical ATS formatting conventions, yielding a 90% score.",
#     "keyword_optimization": "While the resume includes many core keywords, some role‑specific terms (e.g., Prometheus, LangChain, TensorFlow) are absent, giving a moderate 70% score."
#   }
# }

# %%
result_4 = json.loads(ast_result)
result_4
# Out:
# {'total_score': 80,
#  'category_scores': {'skills_match': 63,
#   'experience_relevance': 82,
#   'education_alignment': 100,
#   'format_structure': 90,
#   'keyword_optimization': 70},
#  'weighted_breakdown': {'skills_match_weighted': 19,
#   'experience_relevance_weighted': 21,
#   'education_alignment_weighted': 15,
#   'format_structure_weighted': 14,
#   'keyword_optimization_weighted': 11},
#  'benchmark_comparison': 'Good fit',
#  'confidence_interval': '+/-5%',
#  'reasoning': {'skills_match': 'The candidate’s skill set matches 63% of the key technical requirements across the five job listings, based on the presence of Python, Docker, Kubernetes, AWS, and general machine‑learning terminology.',
#   'experience_relevance': 'With over five years of senior software engineering experience in roles that involve ML and cloud services, the candidate’s experience aligns highly (average 82%) with the experience expectations of the positions.',
#   'education_alignment': 'The candidate holds a B.Tech in Computer Science, which satisfies or exceeds the typical bachelor’s‑level requirement present (or implied) in all five listings; hence 100% alignment.',
#   'format_structure': 'The parsed resume shows a clean, organized structure with distinct sections (contact, skills, experience, education, certifications), meeting typical ATS formatting conventions, yielding a 90% score.',
#   'keyword_optimization': 'While the resume includes many core keywords, some role‑specific terms (e.g., Prometheus, LangChain, TensorFlow) are absent, giving a moderate 70% score.'}}

# %%
def send_ats_score(ats_score,conn,resume_id):
    query = """
    INSERT INTO scores (ats_score,resume_id)
    VALUES (%s,%s)
    """
    try:
        if conn:
            params = (
                json.dumps(ats_score),
                resume_id,
            )
            execute_query(conn,query,params)
            return "Completed"
        else:
            raise Exception("Connection not established")
    except Exception as e:
        return str(e)

# %%
send_ats_score(result_4,conn_online_db,resume_id)
# Out:
# 'Completed'

# %%
from autogen_core import try_get_known_serializers_for_type


def bring_the_ats_score(conn,resume_id):
    query = """
    SELECT ats_score FROM scores WHERE resume_id = %s
    """
    try:
        if conn:
            params = (resume_id,)
            result = execute_query(conn,query,params)
            return result
        else:
            raise Exception("Connection is not established")
    except Exception as e:
        print(f"Error occured while fetching ATs score for resume_id: {resume_id}, Error: {str(e)}")
        return None

# %%
result_5=bring_the_ats_score(conn_online_db,resume_id)
# Out:
# Query Executed

# %%
from typing import List
from pydantic import BaseModel,Field

class ImprovementRecommendations(BaseModel):
    """Schema for ATS improvement suggestions."""

    missing_keywords : List[str] = Field(default_factory=list,
    description="List of important keywords missing from the resume.")

    skill_gaps : List[str] = Field(default_factory=list,
    description="List of skills required by the job but missing from the resume.")

    format_recommendations : List[str] = Field(default_factory=list,
    description="Suggestions for improving resume formatting for ATS parsing.")

    content_optimization : List[str] = Field(default_factory=list,
    description="Suggestions for rewriting or restructuring content.")

    priority_actions: List[str] = Field(default_factory=list, description="Top 3 priority actions to improve score the most.")

# %%
improvement_model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
    api_key = openai_api_key,
    response_format=ImprovementRecommendations
)

# %%
improvement_recommendation = AssistantAgent(
    name = "Improvement_Agent",
    model_client=model_client,
    system_message="""You are an ATS Improvement Recommendation Agent.

Your role:
- Compare a candidate's parsed resume JSON against one or more parsed job description JSONs.
- Use the ATS scoring output (if provided) to identify weak scoring categories.
- Provide detailed, actionable improvements to increase the candidate's score and job fit.

Analysis Steps:
1. **Keyword Match**:
   - Identify missing keywords from the job description(s) that are relevant to the candidate’s background.
   - Suggest exact phrases or skills that should be added to the resume.

2. **Skill Gap Analysis**:
   - Compare required and preferred skills in the job description(s) with the resume’s skill list.
   - Recommend upskilling paths or certifications for missing but important skills.

3. **Format & Structure Recommendations**:
   - Suggest resume formatting improvements for ATS parsing (e.g., section ordering, avoiding tables/images, consistent headings).

4. **Content Optimization**:
   - Recommend restructuring bullet points to be more impactful and keyword-rich.
   - Suggest quantifying achievements (e.g., “Increased sales by 20%” instead of “Helped improve sales”).

Output:
Return only valid JSON in the following format:

Guidelines:
- Be specific — provide examples for improvements.
- Only suggest changes relevant to the job description(s).
- If nothing is missing in a category, return an empty list for that category.
- Do not rewrite the resume — only suggest improvements."""
)

# %%
improve_agent_result = await Console(improvement_recommendation.run_stream(task=TextMessage(content=f"The candidate parsed resume is\n\n\n {content} and the job descriptions are \n\n\n {result_3} and the ats score {result_4}",source="user")))

improve_result = improve_agent_result.messages[-1].content
# Out:
# ---------- TextMessage (user) ----------
# The candidate parsed resume is
#
#
#  {"file_type":"text/plain","name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]} and the job descriptions are
#
#
#  [({'jobs': [{'role': 'Machine Learning Engineer – ML Ops & Support', 'salary': 'Not disclosed', 'company': 'Aera Technology', 'location': 'Pune, Maharashtra', 'job_apply_link': 'https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.'}, {'role': 'AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)', 'salary': 'Not disclosed', 'company': 'vueverse.', 'location': 'Guwahati, Assam', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.'}, {'role': 'Data Scientist (Python and AI/ML)', 'salary': 'Not disclosed', 'company': 'EXL', 'location': 'Noida, Uttar Pradesh', 'job_apply_link': 'https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.'}, {'role': 'Business and Marketing Data Scientist, GTech Ads', 'salary': 'Not disclosed', 'company': 'Google', 'location': 'Mumbai, Maharashtra', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.'}, {'role': 'Machine Learning Engineer, AVP', 'salary': 'Not disclosed', 'company': 'NatWest Digital X', 'location': 'Bengaluru, Karnataka', 'job_apply_link': 'https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.'}]},)] and the ats score **Machine Learning Engineer – ML Ops & Support**
# - **Company:** Aera Technology – Pune, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Key responsibilities:**
#   - Monitor and maintain ML pipelines and services.
#   - Build observability tools and support LLM/Agentic AI features.
#   - Develop internal ML tooling and collaborate with cross‑functional teams.
# - **Required skills:** 3‑5 yrs of software engineering/ML Ops, Python, Docker, Kubernetes, CI/CD, Prometheus/Grafana, AWS.
#
# ---
#
# **AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)**
# - **Company:** vueverse. – Guwahati, Assam
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core focus:** Design & deploy scalable AI/ML & GenAI solutions on cloud for BFSI.
# - **Key skills:** AWS, cloud‑native AI services, MLOps pipelines, LLM tooling (LangChain, Hugging Face).
#
# ---
#
# **Data Scientist (Python and AI/ML)**
# - **Company:** EXL – Noida, Uttar Pradesh
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Role highlights:**
#   - Design, implement, and deploy ML models.
#   - Build pipelines and APIs.
#   - Work with deep learning frameworks.
#
# ---
#
# **Business and Marketing Data Scientist, GTech Ads**
# - **Company:** Google – Mumbai, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Focus area:** Marketing analytics with Python, SQL, ML/AI.
#
# ---
#
# **Machine Learning Engineer, AVP**
# - **Company:** NatWest Digital X – Bengaluru, Karnataka
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core responsibilities:**
#   - Deploy, automate, and monitor ML models at scale.
#   - Use Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, MLOps.
#
# ---
# ---------- TextMessage (Improvement_Agent) ----------
# ```json
# {
#   "keyword_match": [
#     "Add Prometheus and Grafana to the skills list to demonstrate monitoring expertise.",
#     "Include CI/CD tools (GitHub Actions, Jenkins, ArgoCD) to showcase pipeline automation.",
#     "Mention model serving frameworks such as TensorFlow Serving, TorchServe, or SageMaker.",
#     "Add LLM/Agentic AI tools (LangChain, Hugging Face Transformers) to signal familiarity with GenAI.",
#     "Add TensorFlow and/or PyTorch to the skill set to align with deep‑learning requirements.",
#     "Add \"Observability\" and “Model monitoring” phrases in job descriptions.",
#     "Include “AWS SageMaker” or “AWS Lambda” to show cloud‑native AI experience."
#   ],
#   "skill_gap_analysis": [
#     "AWS Certified Developer is good, but consider pursuing AWS Certified Machine Learning – Specialty or MLOps certifications.",
#     "Acquire hands‑on experience or certification in TensorFlow and PyTorch.",
#     "Learn Prometheus, Grafana, and Grafana Loki for observability tooling.",
#     "Get certified in Kubernetes administration (CKA) or Docker (Docker Certified Associate).",
#     "Gain proficiency with LangChain or Hugging Face’s 🤗 Transformers for GenAI roles."
#   ],
#   "format_structure_recommendations": [
#     "Use plain text sections (Summary, Experience, Skills, Projects, Education, Certifications) in that order.",
#     "Avoid tables, images, or complex formatting; stick to bullet points and standard fonts.",
#     "Ensure each section heading is capitalized and consistent (e.g., PROFESSIONAL EXPERIENCE).",
#     "List experiences chronologically with dates and job titles in separate lines for clear parsing.",
#     "Include a skills subsection with bullet‑pointed categories (Programming Languages, Cloud Platforms, MLOps Tools)."
#   ],
#   "content_optimization": [
#     "Rewrite bullets to show impact: e.g., \"Implemented a Docker‑based CI/CD pipeline that reduced model deployment time by 35 % and decreased rollback incidents by 20 %\".",
#     "Quantify achievements: \"Monitored and maintained 12 ML pipelines, achieving 99.8 % uptime across all services.\"",
#     "Add verbs like Designed, Deployed, Optimized, Integrated, and measured outcomes.",
#     "Mention specific model serving metrics (latency, throughput) if possible.",
#     "Include cross‑functional collaboration examples, e.g., \"Worked with data scientists and product managers to deliver real‑time insights via Grafana dashboards.\""
#   ]
# }
# ```

# %%
content
# Out:
# '{"file_type":"text/plain","name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}'

# %%
result_3
# Out:
# [({'jobs': [{'role': 'Machine Learning Engineer – ML Ops & Support',
#      'salary': 'Not disclosed',
#      'company': 'Aera Technology',
#      'location': 'Pune, Maharashtra',
#      'job_apply_link': 'https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic',
#      'employment_type': 'Full‑time',
#      'job_description': 'Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.'},
#     {'role': 'AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)',
#      'salary': 'Not disclosed',
#      'company': 'vueverse.',
#      'location': 'Guwahati, Assam',
#      'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic',
#      'employment_type': 'Full‑time',
#      'job_description': 'Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.'},
#     {'role': 'Data Scientist (Python and AI/ML)',
#      'salary': 'Not disclosed',
#      'company': 'EXL',
#      'location': 'Noida, Uttar Pradesh',
#      'job_apply_link': 'https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic',
#      'employment_type': 'Full‑time',
#      'job_description': 'Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.'},
#     {'role': 'Business and Marketing Data Scientist, GTech Ads',
#      'salary': 'Not disclosed',
#      'company': 'Google',
#      'location': 'Mumbai, Maharashtra',
#      'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic',
#      'employment_type': 'Full‑time',
#      'job_description': 'Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.'},
#     {'role': 'Machine Learning Engineer, AVP',
#      'salary': 'Not disclosed',
#      'company': 'NatWest Digital X',
#      'location': 'Bengaluru, Karnataka',
#      'job_apply_link': 'https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic',
#      'employment_type': 'Full‑time',
#      'job_description': 'Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.'}]},)]

# %%
result_4
# Out:
# '**Machine Learning Engineer – ML Ops & Support**  \n- **Company:** Aera Technology – Pune, Maharashtra  \n- **Employment type:** Full‑time  \n- **Salary:** Not disclosed  \n- **Apply link:** <https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \n- **Key responsibilities:**  \n  - Monitor and maintain ML pipelines and services.  \n  - Build observability tools and support LLM/Agentic AI features.  \n  - Develop internal ML tooling and collaborate with cross‑functional teams.  \n- **Required skills:** 3‑5\u202fyrs of software engineering/ML Ops, Python, Docker, Kubernetes, CI/CD, Prometheus/Grafana, AWS.  \n\n---\n\n**AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)**  \n- **Company:** vueverse. – Guwahati, Assam  \n- **Employment type:** Full‑time  \n- **Salary:** Not disclosed  \n- **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \n- **Core focus:** Design & deploy scalable AI/ML & GenAI solutions on cloud for BFSI.  \n- **Key skills:** AWS, cloud‑native AI services, MLOps pipelines, LLM tooling (LangChain, Hugging Face).  \n\n---\n\n**Data Scientist (Python and AI/ML)**  \n- **Company:** EXL – Noida, Uttar Pradesh  \n- **Employment type:** Full‑time  \n- **Salary:** Not disclosed  \n- **Apply link:** <https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \n- **Role highlights:**  \n  - Design, implement, and deploy ML models.  \n  - Build pipelines and APIs.  \n  - Work with deep learning frameworks.  \n\n---\n\n**Business and Marketing Data Scientist, GTech Ads**  \n- **Company:** Google – Mumbai, Maharashtra  \n- **Employment type:** Full‑time  \n- **Salary:** Not disclosed  \n- **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \n- **Focus area:** Marketing analytics with Python, SQL, ML/AI.  \n\n---\n\n**Machine Learning Engineer, AVP**  \n- **Company:** NatWest Digital X – Bengaluru, Karnataka  \n- **Employment type:** Full‑time  \n- **Salary:** Not disclosed  \n- **Apply link:** <https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \n- **Core responsibilities:**  \n  - Deploy, automate, and monitor ML models at scale.  \n  - Use Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, MLOps.  \n\n---'

# %%
json.dumps(result_5)
# Out:
# '[["**Machine Learning Engineer \\u2013 ML Ops & Support**  \\n- **Company:** Aera Technology \\u2013 Pune, Maharashtra  \\n- **Employment type:** Full\\u2011time  \\n- **Salary:** Not disclosed  \\n- **Apply link:** <https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \\n- **Key responsibilities:**  \\n  - Monitor and maintain ML pipelines and services.  \\n  - Build observability tools and support LLM/Agentic AI features.  \\n  - Develop internal ML tooling and collaborate with cross\\u2011functional teams.  \\n- **Required skills:** 3\\u20115\\u202fyrs of software engineering/ML Ops, Python, Docker, Kubernetes, CI/CD, Prometheus/Grafana, AWS.  \\n\\n---\\n\\n**AI/ML Solutions Architect \\u2013 GenAI & Cloud (BFSI Focus)**  \\n- **Company:** vueverse. \\u2013 Guwahati, Assam  \\n- **Employment type:** Full\\u2011time  \\n- **Salary:** Not disclosed  \\n- **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \\n- **Core focus:** Design & deploy scalable AI/ML & GenAI solutions on cloud for BFSI.  \\n- **Key skills:** AWS, cloud\\u2011native AI services, MLOps pipelines, LLM tooling (LangChain, Hugging Face).  \\n\\n---\\n\\n**Data Scientist (Python and AI/ML)**  \\n- **Company:** EXL \\u2013 Noida, Uttar Pradesh  \\n- **Employment type:** Full\\u2011time  \\n- **Salary:** Not disclosed  \\n- **Apply link:** <https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \\n- **Role highlights:**  \\n  - Design, implement, and deploy ML models.  \\n  - Build pipelines and APIs.  \\n  - Work with deep learning frameworks.  \\n\\n---\\n\\n**Business and Marketing Data Scientist, GTech Ads**  \\n- **Company:** Google \\u2013 Mumbai, Maharashtra  \\n- **Employment type:** Full\\u2011time  \\n- **Salary:** Not disclosed  \\n- **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \\n- **Focus area:** Marketing analytics with Python, SQL, ML/AI.  \\n\\n---\\n\\n**Machine Learning Engineer, AVP**  \\n- **Company:** NatWest Digital X \\u2013 Bengaluru, Karnataka  \\n- **Employment type:** Full\\u2011time  \\n- **Salary:** Not disclosed  \\n- **Apply link:** <https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>  \\n- **Core responsibilities:**  \\n  - Deploy, automate, and monitor ML models at scale.  \\n  - Use Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, MLOps.  \\n\\n---"]]'

# %%
def send_improve_to_score(result,conn,resume_id):
    query = """
    UPDATE scores SET recommendations = %s where resume_id = %s;
    """
    try:
        if conn:
            params = (json.dumps(result),resume_id,)
            execute_query(conn,query,params)
            return "Completed"
        else:
            raise Exception("Connection is not established")
    except Exception as e:
        print(f"Error occured while fetching ATs score for resume_id: {resume_id}, Error: {str(e)}")
        return None

# %%
send_improve_to_score(result_5,conn_online_db,resume_id)
# Out:
# 'Completed'

# %%
groq_api_key = os.getenv('GROQ_API_KEY')

# %%
groq_client = OpenAIChatCompletionClient(
    base_url="https://api.groq.com/openai/v1",  # Groq's OpenAI-compatible endpoint
    model="openai/gpt-oss-20b",  # Example model, you can change this to other available Groq models
    api_key=groq_api_key,  # Your Groq API key
    model_info={
        "family": "groq",
        "vision": False,  # Most Groq models don't support vision
        "function_calling": True,  # Check Groq's documentation for specific model capabilities
        "json_output": False,
        "multiple_system_messages": True,
    }
)

# %%
summary_agent = AssistantAgent(
    name="summarizer_agent",
    model_client=groq_client,
    system_message="""
You are an ATS Summary Agent.

Your job:
- Take structured JSON from the ATS scoring, improvement recommendations, and optionally the parsed job description.
- Convert these into a clear, concise, and encouraging detailed summary for the candidate.
- The goal is to help the candidate understand:
  1. Their overall ATS score and what it means.
  2. Key strengths.
  3. Areas needing improvement.
  4. Concrete next steps they can take.

Guidelines:
- Be professional but friendly.
- Avoid overly technical ATS terms unless explained simply.
- Keep paragraphs short and scannable.
- Use bullet points for recommendations.

Example Output Format:

"Your overall ATS score is **72/100**, which is considered a **Good Fit** for the jobs you can target.

**Strengths:**
- Strong alignment with required experience (8+ years relevant).
- Education fully matches or exceeds requirements.
- Resume structure is clean and ATS-friendly.

**Areas for Improvement:**
- Missing several high-value keywords: AWS Lambda, API Gateway, Terraform.
- Format could benefit from more action verbs and quantifiable results.
- Some job-specific skills not highlighted enough.

**Next Steps:**
1. Add missing keywords naturally into your work experience section.
2. Emphasize AWS-related projects with measurable impact.
3. Include a dedicated skills section listing relevant technologies.

With these adjustments, your score could increase by 10–15 points, moving you into the Excellent Fit range."

Instructions:
- Do not return raw JSON — return plain text suitable for displaying directly to the user.
- Pull information from all provided JSONs.
"""
)

# %%
from asyncio import Task
from typing import Text


summary_agent_result = await Console(summary_agent.run_stream(task=TextMessage(content=f"The candidate parsed resume is\n\n\n {content} and the job descriptions are \n\n\n {result_3} and the ats score {result_4}",source="user")))

summary_result = summary_agent_result.messages[-1].content
# Out:
# ---------- TextMessage (user) ----------
# The candidate parsed resume is
#
#
#  {"file_type":"text/plain","name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]} and the job descriptions are
#
#
#  [({'jobs': [{'role': 'Machine Learning Engineer – ML Ops & Support', 'salary': 'Not disclosed', 'company': 'Aera Technology', 'location': 'Pune, Maharashtra', 'job_apply_link': 'https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Aera Technology is seeking a Machine Learning Engineer (Support & Ops) to ensure AI‑powered decision systems run reliably at scale. Responsibilities include monitoring and maintaining ML pipelines and services, building observability tools, supporting LLM/Agentic AI features, developing internal ML tooling, and collaborating with cross‑functional teams. Required skills: 3‑5 years of software engineering/ML Ops experience, strong Python, containerization (Docker, Kubernetes), CI/CD, monitoring tools (Prometheus, Grafana), and model serving frameworks. Familiarity with AWS, Docker, Kubernetes, and Python aligns well with the candidate’s skill set.'}, {'role': 'AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)', 'salary': 'Not disclosed', 'company': 'vueverse.', 'location': 'Guwahati, Assam', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior AI/ML Solutions Architect role focused on designing and deploying scalable AI/ML and GenAI solutions on cloud platforms for the BFSI sector. Requires deep expertise in AWS, cloud‑native AI services, MLOps pipelines, and LLM tooling (e.g., LangChain, Hugging Face). The candidate’s experience with AWS, Python, Docker, Kubernetes, and ML engineering is highly relevant.'}, {'role': 'Data Scientist (Python and AI/ML)', 'salary': 'Not disclosed', 'company': 'EXL', 'location': 'Noida, Uttar Pradesh', 'job_apply_link': 'https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist position requiring 4+ years of experience with Python, AI/ML, and cloud services. Responsibilities include designing, implementing, and deploying ML models, building pipelines and APIs, and working with deep learning frameworks. The role matches the candidate’s Python, SQL, and AWS skill set.'}, {'role': 'Business and Marketing Data Scientist, GTech Ads', 'salary': 'Not disclosed', 'company': 'Google', 'location': 'Mumbai, Maharashtra', 'job_apply_link': 'https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Data Scientist role focusing on marketing analytics, requiring Python, SQL, and ML/AI experience. Involves building models, delivering insights, and collaborating with cross‑functional teams. The candidate’s strong Python and ML background aligns well.'}, {'role': 'Machine Learning Engineer, AVP', 'salary': 'Not disclosed', 'company': 'NatWest Digital X', 'location': 'Bengaluru, Karnataka', 'job_apply_link': 'https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'employment_type': 'Full‑time', 'job_description': 'Senior ML Engineer role responsible for deploying, automating, and monitoring ML models at scale. Requires experience with Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, and MLOps. The candidate’s background in Python, AWS, Docker, Kubernetes, and machine learning matches the requirements.'}]},)] and the ats score **Machine Learning Engineer – ML Ops & Support**
# - **Company:** Aera Technology – Pune, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Key responsibilities:**
#   - Monitor and maintain ML pipelines and services.
#   - Build observability tools and support LLM/Agentic AI features.
#   - Develop internal ML tooling and collaborate with cross‑functional teams.
# - **Required skills:** 3‑5 yrs of software engineering/ML Ops, Python, Docker, Kubernetes, CI/CD, Prometheus/Grafana, AWS.
#
# ---
#
# **AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)**
# - **Company:** vueverse. – Guwahati, Assam
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core focus:** Design & deploy scalable AI/ML & GenAI solutions on cloud for BFSI.
# - **Key skills:** AWS, cloud‑native AI services, MLOps pipelines, LLM tooling (LangChain, Hugging Face).
#
# ---
#
# **Data Scientist (Python and AI/ML)**
# - **Company:** EXL – Noida, Uttar Pradesh
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Role highlights:**
#   - Design, implement, and deploy ML models.
#   - Build pipelines and APIs.
#   - Work with deep learning frameworks.
#
# ---
#
# **Business and Marketing Data Scientist, GTech Ads**
# - **Company:** Google – Mumbai, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Focus area:** Marketing analytics with Python, SQL, ML/AI.
#
# ---
#
# **Machine Learning Engineer, AVP**
# - **Company:** NatWest Digital X – Bengaluru, Karnataka
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core responsibilities:**
#   - Deploy, automate, and monitor ML models at scale.
#   - Use Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, MLOps.
#
# ---
# ---------- TextMessage (summarizer_agent) ----------
# Your overall ATS score for the **Machine Learning Engineer – ML Ops & Support** role at Aera Technology is **~75 / 100** (a **Good Fit**).
# This means your resume matches many of the key requirements, but there are still a few gaps that could push you into the “Excellent Fit” band.
#
# ---
#
# ## Strengths
# - **Relevant Technical Skills** – Python, Docker, Kubernetes, and AWS are core to the role.
# - **Professional Experience** – Two senior‑level software engineering roles (3 + years).
# - **Certification** – AWS Certified Developer, reinforcing your cloud‑native expertise.
# - **Clear Career Progression** – Promotion from Software Engineer to Senior Software Engineer shows growth.
#
# ---
#
# ## Areas for Improvement
# - **Missing MLOps‑Specific Keywords** – CI/CD, Prometheus, Grafana, and monitoring tools are not highlighted.
# - **Quantified Impact** – No concrete results (e.g., “improved deployment speed by 30 %”).
# - **ML Ops Experience** – Brief mention of ML pipelines or model serving is lacking.
# - **Documentation & Observability** – No evidence of building observability tools or supporting LLM features.
#
# ---
#
# ## Next Steps
# 1. **Add MLOps Keywords**
#    - Insert *CI/CD*, *Prometheus*, *Grafana*, *model serving*, and *observability* into the experience section.
# 2. **Show Measurable Results**
#    - “Reduced model deployment time from X hours to X minutes using automated CI/CD pipelines.”
# 3. **Highlight ML Ops Work**
#    - If you have built or maintained ML pipelines, add a bullet:
#      *Designed and maintained production‑grade ML pipelines using Docker, Kubernetes, and AWS SageMaker.*
# 4. **Include a Dedicated Skills/Toolbox Section**
#    - List: Python, SQL, Java, Machine Learning, AWS (Developer), Docker, Kubernetes, CI/CD tools (Jenkins/Argo), Prometheus, Grafana, SageMaker.
# 5. **Add a Short “Key Accomplishments” Sub‑section**
#    - “Led the migration of 10+ data pipelines to AWS, cutting costs by 20 %.”
#
# With these adjustments, you should see a 10–15‑point lift in your ATS score, putting you firmly in the **Excellent Fit** range for roles like this one and similar positions at vueverse, EXL, Google, and NatWest Digital X. Good luck!

# %% [markdown]
# ## Creating RAG

# %%
from autogen_core.memory import MemoryContent,MemoryMimeType
from autogen_ext.memory.mem0 import Mem0Memory

# %%
import json

mem0_memory = Mem0Memory(
    is_cloud=True,
    api_key = "m0-QXXhimSTpF0BvB3Gf3COiZIG85WknDgFbrkQDBWd",
    limit=3,
    user_id="ats_id"
)

openai_model_client = OpenAIChatCompletionClient(
    model="gpt-4o",
    api_key=openai_api_key
)

file_path = "realistic_rag_benchmarks.jsonl"

with open(file_path,"r",encoding="utf-8") as file:
    for line in file:
        entry = json.loads(line.strip())
        print(entry)

        await mem0_memory.add(
            MemoryContent(
                content=entry['content'],
                mime_type=MemoryMimeType.TEXT,
                metadata=entry['metadata']
            )
        )
# Out:
# {'content': 'In Tech, the industry standard for skills match is 85%.', 'metadata': {'category': 'skills_match', 'industry': 'Tech', 'type': 'best_practice', 'industry_standard': 85, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Tech, the industry standard for experience relevance is 90%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Tech', 'type': 'best_practice', 'industry_standard': 90, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Tech, the industry standard for education alignment is 95%.', 'metadata': {'category': 'education_alignment', 'industry': 'Tech', 'type': 'best_practice', 'industry_standard': 95, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Tech, the industry standard for format structure is 90%.', 'metadata': {'category': 'format_structure', 'industry': 'Tech', 'type': 'best_practice', 'industry_standard': 90, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Tech, the industry standard for keyword optimization is 80%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Tech', 'type': 'best_practice', 'industry_standard': 80, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}
# {'content': 'In Finance, the industry standard for skills match is 80%.', 'metadata': {'category': 'skills_match', 'industry': 'Finance', 'type': 'best_practice', 'industry_standard': 80, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Finance, the industry standard for experience relevance is 88%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Finance', 'type': 'best_practice', 'industry_standard': 88, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Finance, the industry standard for education alignment is 92%.', 'metadata': {'category': 'education_alignment', 'industry': 'Finance', 'type': 'best_practice', 'industry_standard': 92, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Finance, the industry standard for format structure is 88%.', 'metadata': {'category': 'format_structure', 'industry': 'Finance', 'type': 'best_practice', 'industry_standard': 88, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Finance, the industry standard for keyword optimization is 78%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Finance', 'type': 'best_practice', 'industry_standard': 78, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}
# {'content': 'In Healthcare, the industry standard for skills match is 78%.', 'metadata': {'category': 'skills_match', 'industry': 'Healthcare', 'type': 'best_practice', 'industry_standard': 78, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Healthcare, the industry standard for experience relevance is 92%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Healthcare', 'type': 'best_practice', 'industry_standard': 92, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Healthcare, the industry standard for education alignment is 90%.', 'metadata': {'category': 'education_alignment', 'industry': 'Healthcare', 'type': 'best_practice', 'industry_standard': 90, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Healthcare, the industry standard for format structure is 85%.', 'metadata': {'category': 'format_structure', 'industry': 'Healthcare', 'type': 'best_practice', 'industry_standard': 85, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Healthcare, the industry standard for keyword optimization is 75%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Healthcare', 'type': 'best_practice', 'industry_standard': 75, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}
# {'content': 'In Marketing, the industry standard for skills match is 75%.', 'metadata': {'category': 'skills_match', 'industry': 'Marketing', 'type': 'best_practice', 'industry_standard': 75, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Marketing, the industry standard for experience relevance is 85%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Marketing', 'type': 'best_practice', 'industry_standard': 85, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Marketing, the industry standard for education alignment is 88%.', 'metadata': {'category': 'education_alignment', 'industry': 'Marketing', 'type': 'best_practice', 'industry_standard': 88, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Marketing, the industry standard for format structure is 80%.', 'metadata': {'category': 'format_structure', 'industry': 'Marketing', 'type': 'best_practice', 'industry_standard': 80, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Marketing, the industry standard for keyword optimization is 85%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Marketing', 'type': 'best_practice', 'industry_standard': 85, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}
# {'content': 'In Education, the industry standard for skills match is 70%.', 'metadata': {'category': 'skills_match', 'industry': 'Education', 'type': 'best_practice', 'industry_standard': 70, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Education, the industry standard for experience relevance is 80%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Education', 'type': 'best_practice', 'industry_standard': 80, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Education, the industry standard for education alignment is 95%.', 'metadata': {'category': 'education_alignment', 'industry': 'Education', 'type': 'best_practice', 'industry_standard': 95, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Education, the industry standard for format structure is 82%.', 'metadata': {'category': 'format_structure', 'industry': 'Education', 'type': 'best_practice', 'industry_standard': 82, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Education, the industry standard for keyword optimization is 72%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Education', 'type': 'best_practice', 'industry_standard': 72, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}
# {'content': 'In Engineering, the industry standard for skills match is 82%.', 'metadata': {'category': 'skills_match', 'industry': 'Engineering', 'type': 'best_practice', 'industry_standard': 82, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Engineering, the industry standard for experience relevance is 88%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Engineering', 'type': 'best_practice', 'industry_standard': 88, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Engineering, the industry standard for education alignment is 92%.', 'metadata': {'category': 'education_alignment', 'industry': 'Engineering', 'type': 'best_practice', 'industry_standard': 92, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Engineering, the industry standard for format structure is 88%.', 'metadata': {'category': 'format_structure', 'industry': 'Engineering', 'type': 'best_practice', 'industry_standard': 88, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Engineering, the industry standard for keyword optimization is 78%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Engineering', 'type': 'best_practice', 'industry_standard': 78, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}
# {'content': 'In Retail, the industry standard for skills match is 68%.', 'metadata': {'category': 'skills_match', 'industry': 'Retail', 'type': 'best_practice', 'industry_standard': 68, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Retail, the industry standard for experience relevance is 75%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Retail', 'type': 'best_practice', 'industry_standard': 75, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Retail, the industry standard for education alignment is 80%.', 'metadata': {'category': 'education_alignment', 'industry': 'Retail', 'type': 'best_practice', 'industry_standard': 80, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Retail, the industry standard for format structure is 78%.', 'metadata': {'category': 'format_structure', 'industry': 'Retail', 'type': 'best_practice', 'industry_standard': 78, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Retail, the industry standard for keyword optimization is 65%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Retail', 'type': 'best_practice', 'industry_standard': 65, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}
# {'content': 'In Hospitality, the industry standard for skills match is 65%.', 'metadata': {'category': 'skills_match', 'industry': 'Hospitality', 'type': 'best_practice', 'industry_standard': 65, 'unit': 'percent', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording']}}
# {'content': 'In Hospitality, the industry standard for experience relevance is 70%.', 'metadata': {'category': 'experience_relevance', 'industry': 'Hospitality', 'type': 'best_practice', 'industry_standard': 70, 'unit': 'percent', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting']}}
# {'content': 'In Hospitality, the industry standard for education alignment is 75%.', 'metadata': {'category': 'education_alignment', 'industry': 'Hospitality', 'type': 'best_practice', 'industry_standard': 75, 'unit': 'percent', 'common_gaps': ['Degree not listed', 'Missing certifications', 'Old or irrelevant education'], 'optimization_tips': ['Include degree, institution, and graduation year', 'Add current certifications', 'Show coursework if relevant']}}
# {'content': 'In Hospitality, the industry standard for format structure is 72%.', 'metadata': {'category': 'format_structure', 'industry': 'Hospitality', 'type': 'best_practice', 'industry_standard': 72, 'unit': 'percent', 'common_gaps': ['Inconsistent formatting', 'Missing headings', 'Overuse of graphics'], 'optimization_tips': ['Use consistent bullet styles', 'Add clear section headings', 'Avoid graphics and tables']}}
# {'content': 'In Hospitality, the industry standard for keyword optimization is 60%.', 'metadata': {'category': 'keyword_optimization', 'industry': 'Hospitality', 'type': 'best_practice', 'industry_standard': 60, 'unit': 'percent', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions']}}

# %%
openai_model_client = OpenAIChatCompletionClient(
    model="gpt-4o",
    api_key=openai_api_key,
    model_info={
        "multiple_system_messages":True,
        "vision":False,
        "function_calling":True,
        "json_output":False,
        "family":"gpt-4o"
    }
)
mem0_memory = Mem0Memory(
    is_cloud=True,
    api_key = "m0-QXXhimSTpF0BvB3Gf3COiZIG85WknDgFbrkQDBWd",
    limit=3,
    user_id="ats_id"
)
# Out:
# c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:453: UserWarning: Missing required field 'structured_output' in ModelInfo. This field will be required in a future version of AutoGen.
#   validate_model_info(self._model_info)

# %%
assistant = AssistantAgent(
    name = "assistants",
    model_client= groq_client,
    memory = [mem0_memory],
    system_message="""You are a Visualization Agent in an ATS scoring system. Your responsibilities are:

Task Overview:
1. Retrieve and Compare Data
   - Receive ATS scoring data from user input.
   - Retrieve corresponding industry benchmarks from memory.

2. Generate Visualizations using Python
   - Bar Chart: Compare user scores vs. industry benchmarks for each category.
   - Pie Chart: Show weighted score contributions of each category.
   - Radar Chart: Show category performance distribution.
   - I want them to be combined in a same png file with name "combine_chart.png".
   - At last print something like this "print("Charts generated")"

3. Code Generation Requirements
   - Write the Python code using matplotlib and seaborn.
   - Include code to save the generated images in the same directory.
   - Structure the code in a single code block.
   - You have to write the code in the example format:
     ```python
     code = '''
         print("Hello World")
     '''
     with open('temp/sample.png', 'w') as f:
         f.write(code)
         print("Code saved successfully in solution.py")
     ```

4. Response Structure
   - Step 1: Explain your plan to solve the task.
   - Step 2: Provide the Python code inside a single code block.
   - Step 3: After execution, send the code to visualizer agent make sure the code only have matplotlib, seaborn and numpy import.

Important Notes:
- Always ensure the charts accurately reflect user scores vs. industry benchmarks.
- Ensure the pie chart correctly uses weighted contributions.
- Radar chart axes must correspond to each scoring category.
- Do not split code into multiple blocks.
- Follow the template strictly for saving the code."""
)

# stream = assistant.run_stream(task=f"The ats score of the user resume is {result_4}")
# await Console(stream)

# %%
from autogen_ext.code_executors.docker import DockerCommandLineCodeExecutor

# %%
visualization_agent = AssistantAgent(
    name="Visulizer_Agent",
    model_client=groq_client,
    system_message="The assistant will research and give you the code for creating the graph you have to just send the python scripts to the code executor agent provided by the assistant if any error occurs try to fix it and give the code again to the code executor agent. Stricltly only give the ```python code to the code executor agent. You dont have use import os or anything just give the code what you have received from the assistant agent. "
)

# %%
docker = DockerCommandLineCodeExecutor(
    image="python-with-matplotlib-and-seaborn",
    work_dir = "temp",
    timeout=120
)

# %%
from autogen_agentchat.agents import CodeExecutorAgent
code_executor_agent = CodeExecutorAgent(
    name="Code_Executor_Agent",
    code_executor=docker
)

# %%
await docker.start()

# %%
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import TextMentionTermination

sample_team = RoundRobinGroupChat(
    participants=[assistant],
    termination_condition=TextMentionTermination("STOP"),
    max_turns = 5
)
async def main():
    task = f"The ATS score of the candidate resume is {result_4}"
    await Console(sample_team.run_stream(task=task))
    if assistant.name:
        print("Yes assistant is called")

await main()
# Out:
# ---------- TextMessage (user) ----------
# The ATS score of the candidate resume is **Machine Learning Engineer – ML Ops & Support**
# - **Company:** Aera Technology – Pune, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/machine-learning-engineer-%E2%80%93-ml-ops-support-at-aera-technology-4285700571?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Key responsibilities:**
#   - Monitor and maintain ML pipelines and services.
#   - Build observability tools and support LLM/Agentic AI features.
#   - Develop internal ML tooling and collaborate with cross‑functional teams.
# - **Required skills:** 3‑5 yrs of software engineering/ML Ops, Python, Docker, Kubernetes, CI/CD, Prometheus/Grafana, AWS.
#
# ---
#
# **AI/ML Solutions Architect – GenAI & Cloud (BFSI Focus)**
# - **Company:** vueverse. – Guwahati, Assam
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167324902&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core focus:** Design & deploy scalable AI/ML & GenAI solutions on cloud for BFSI.
# - **Key skills:** AWS, cloud‑native AI services, MLOps pipelines, LLM tooling (LangChain, Hugging Face).
#
# ---
#
# **Data Scientist (Python and AI/ML)**
# - **Company:** EXL – Noida, Uttar Pradesh
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://in.linkedin.com/jobs/view/data-scientist-python-and-ai-ml-at-exl-4285700271?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Role highlights:**
#   - Design, implement, and deploy ML models.
#   - Build pipelines and APIs.
#   - Work with deep learning frameworks.
#
# ---
#
# **Business and Marketing Data Scientist, GTech Ads**
# - **Company:** Google – Mumbai, Maharashtra
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://en-in.whatjobs.com/jobs/machine-learning?id=167371241&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Focus area:** Marketing analytics with Python, SQL, ML/AI.
#
# ---
#
# **Machine Learning Engineer, AVP**
# - **Company:** NatWest Digital X – Bengaluru, Karnataka
# - **Employment type:** Full‑time
# - **Salary:** Not disclosed
# - **Apply link:** <https://jobs.natwestgroup.com/jobs/16389032-machine-learning-engineer-avp?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic>
# - **Core responsibilities:**
#   - Deploy, automate, and monitor ML models at scale.
#   - Use Python, TensorFlow/PyTorch, AWS/GCP/Azure, Docker, CI/CD, MLOps.
#
# ---
# ---------- MemoryQueryEvent (assistants) ----------
# [MemoryContent(content='In Engineering, the industry standard for skills match is 82%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Engineering', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 82, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.46278589963912964, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 856863, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 880011, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Engineering, the industry standard for keyword optimization is 78%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Engineering', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 78, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.45457318154413673, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 57, 891488, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 57, 912375, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Healthcare, the industry standard for keyword optimization is 75%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Healthcare', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 75, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.44854543643106126, 'created_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 592166, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 612989, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Education, the industry standard for keyword optimization is 72%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Education', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 72, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.4483550488948822, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 31, 8658, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 15, 47, 134503, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Healthcare, the industry standard for skills match is 78%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Healthcare', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 78, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.44460242986679077, 'created_at': datetime.datetime(2025, 8, 13, 4, 12, 48, 958124, tzinfo=datetime.timezone(datetime.timedelta(days ...
# **Step 1 – Plan**
#
# 1. **Verify Input**
#    The user has provided several job postings but **no ATS scoring data** (scores for each category such as “skills match”, “keyword optimisation”, “experience relevance”, etc.).
#    To create the bar, pie, and radar charts we need:
#    - **Candidate ATS scores** for each relevant category.
#    - **Industry benchmark values** for the same categories (already stored in memory).
#
# 2. **What We’ll Do**
#    *Ask the user for the missing ATS scores.*
#    Once the scores are supplied, we’ll:
#    - Load the industry benchmarks from the provided memory entries.
#    - Build three plots (bar, pie, radar) and combine them into a single PNG (`combine_chart.png`).
#    - Save the script in the prescribed format.
#
# 3. **Next Action**
#    Request the user’s ATS scoring data for each relevant category. This will allow us to proceed with generating the visualizations.
#
# ---
#
# **Step 2 – Request Missing Information**
#
# Could you please provide the candidate’s ATS scores for the following categories (values should be percentages from 0 to 100):
#
# - Skills Match
# - Keyword Optimisation
# - Experience Relevance
# - (Any other relevant categories you have)
#
# Once we have these values, I’ll generate the complete Python code that creates the combined chart.
# ---------- MemoryQueryEvent (assistants) ----------
# [MemoryContent(content='In Healthcare, the industry standard for keyword optimization is 75%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Healthcare', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 75, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.4699752768866853, 'created_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 592166, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 612989, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Education, the industry standard for keyword optimization is 72%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Education', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 72, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.46974578680123247, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 31, 8658, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 15, 47, 134503, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Tech, the industry standard for experience relevance is 90%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'experience_relevance', 'industry': 'Tech', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'industry_standard': 90, 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting'], 'score': 0.46480403945434157, 'created_at': datetime.datetime(2025, 8, 13, 4, 10, 51, 129376, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 10, 51, 150829, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details', 'technology']}), MemoryContent(content='In Education, the industry standard for experience relevance is 80%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'experience_relevance', 'industry': 'Education', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'industry_standard': 80, 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting'], 'score': 0.46395102573024927, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 7, 20376, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 15, 7, 39378, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Engineering, the industry standard for skills match is 82%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Engineering', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 82, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.46320906500762393, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 856863, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=612 ...
# **Step 1 – Plan**
#
# 1. **Identify Missing Data**
#    The task requires candidate ATS scores (e.g., Skills Match, Keyword Optimisation, Experience Relevance, etc.) to compare against industry benchmarks.
#    The current message lists several job postings but **no ATS scores** are provided.
#
# 2. **Next Step**
#    We need those scores to generate the bar, pie, and radar charts.
#    Please supply the candidate’s ATS scoring percentages for each relevant category (e.g., Skills Match %, Keyword Optimisation %, Experience Relevance %, etc.). Once I have those values, I’ll produce the Python code that creates and saves the combined chart.
# ---------- MemoryQueryEvent (assistants) ----------
# [MemoryContent(content='In Healthcare, the industry standard for keyword optimization is 75%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Healthcare', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 75, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.5358157317583541, 'created_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 592166, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 612989, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Healthcare, the industry standard for skills match is 78%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Healthcare', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 78, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.5350404658889503, 'created_at': datetime.datetime(2025, 8, 13, 4, 12, 48, 958124, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 12, 48, 980376, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Engineering, the industry standard for skills match is 82%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Engineering', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 82, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.534069267864868, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 856863, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 880011, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Education, the industry standard for keyword optimization is 72%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Education', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 72, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.5307485740930701, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 31, 8658, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 15, 47, 134503, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Tech, the industry standard for skills match is 85%', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'experience_relevance', 'industry': 'Tech', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'industry_standard': 90, 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting'], 'score': 0.5283443579058017, 'created_at': datetime.datetime(2025, 8, 13, 4, 10, 23, 485822, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'u ...
# **Step 1 – Plan**
#
# 1. **Missing Information**
#    The visualization requires the candidate’s ATS scores for each category (e.g., Skills Match, Keyword Optimisation, Experience Relevance, etc.).
#    These scores are essential to generate the bar, pie, and radar charts and to compare them against the industry benchmarks stored in memory.
#
# 2. **What I’ll Do**
#    • Ask the user to provide the candidate’s ATS scores (percentages) for each relevant category.
#    • Once the scores are available, I will supply the complete Python script that produces the combined `combine_chart.png` using `matplotlib` and `seaborn`.
#
# **Step 2 – Request for Scores**
#
# Could you please provide the candidate’s ATS scores (values in % from 0 to 100) for the following categories:
#
# - Skills Match
# - Keyword Optimisation
# - Experience Relevance
# - (Any other relevant categories you have)
#
# Once I have those numbers, I’ll generate the full code.
# ---------- MemoryQueryEvent (assistants) ----------
# [MemoryContent(content='In Engineering, the industry standard for skills match is 82%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Engineering', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 82, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.4982710181636234, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 856863, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 880011, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Tech, the industry standard for skills match is 85%', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'experience_relevance', 'industry': 'Tech', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'industry_standard': 90, 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting'], 'score': 0.49640503547162407, 'created_at': datetime.datetime(2025, 8, 13, 4, 10, 23, 485822, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 10, 49, 366987, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details', 'technology']}), MemoryContent(content='In Healthcare, the industry standard for skills match is 78%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Healthcare', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 78, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.492253332868418, 'created_at': datetime.datetime(2025, 8, 13, 4, 12, 48, 958124, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 12, 48, 980376, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Healthcare, the industry standard for keyword optimization is 75%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Healthcare', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 75, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.49094010754527284, 'created_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 592166, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 612989, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Education, the industry standard for keyword optimization is 72%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Education', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 72, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.49038097205048725, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 31, 8658, tzinfo=datetime.timezone(datetime.timede ...
# ---------- TextMessage (assistants) ----------
# **Step 1 – Plan**
#
# The charts need the candidate’s ATS scores for each category (e.g., Skills Match, Keyword Optimisation, Experience Relevance, etc.) to compare against the industry benchmarks that are already stored in memory.
#
# **Step 2 – Request for Scores**
#
# Could you please provide the candidate’s ATS scores (percentages from 0 to 100) for the following categories:
#
# - **Skills Match**
# - **Keyword Optimisation**
# - **Experience Relevance**
# - (Any other categories you have)
#
# Once I have those numbers, I’ll generate the Python code that creates and saves the combined `combine_chart.png`.
# ---------- MemoryQueryEvent (assistants) ----------
# [MemoryContent(content='In Healthcare, the industry standard for keyword optimization is 75%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Healthcare', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 75, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.5407667321195284, 'created_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 592166, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 13, 33, 612989, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Engineering, the industry standard for skills match is 82%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Engineering', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 82, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.5392930186216234, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 856863, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 880011, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Education, the industry standard for keyword optimization is 72%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Education', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 72, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.5392794287634246, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 31, 8658, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 15, 47, 134503, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Engineering, the industry standard for keyword optimization is 78%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Engineering', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 78, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.5306919813156166, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 57, 891488, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 57, 912375, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Healthcare, the industry standard for skills match is 78%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Healthcare', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 78, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.530269948824052, 'created_at': datetime.datetime(2025, 8, 13, 4, 12, 48, 958124, tzinfo=datetime.timezone(datetime.timedelta(days=-1,  ...
# ---------- TextMessage (assistants) ----------
# **Step 1 – Plan**
#
# The combined charts (bar, pie, radar) need the candidate’s ATS scores for each category so we can compare them to the industry benchmarks stored in memory.
#
# **Step 2 – Request for Scores**
#
# Could you please provide the candidate’s ATS scores (percentages from 0 to 100) for the following categories?
#
# 1. **Skills Match**
# 2. **Keyword Optimisation**
# 3. **Experience Relevance**
# 4. (Add any other relevant categories you have)
#
# Once we have those values, I’ll generate the complete Python script that creates and saves `combine_chart.png`.
# Yes assistant is called

# %% [markdown]
# ### Agent 1

# %%
extracted_text_json = AssistantAgent(
    name="json_extractor",
    model_client= json_model_client,
    system_message="""You are a resume parser agent when you are given a resume text, you will extract the information from the resume and return it in a json format. In the extracted text there is also file_type written as starting""")

# %% [markdown]
# ### Agent 2

# %%
job_description_agent = AssistantAgent(
    name="Job_Description_Agent",
    model_client= model_client,
    system_message="""
    You are a job description agent. You have been provided a tool name JobFinder where you can query job based on the user parsed resume and give him top 5 jobs for him make sure you follow the the given format and give the answer in json format only 
    When using the tool just write query in 2 words like "python developer" or "Machine Developer" not more than that. 
    In the api call result you wil get apply link make sure to add this.
    """,
    tools=[JobFinder],
    reflect_on_tool_use=True
)

# %% [markdown]
# ### Agent 3

# %%
avaible_job_agent = AssistantAgent(
    name="avaible_job",
    model_client= model_client,
    system_message= """You are a available job agent which get data about jobs the user can do based on his/her resume in json format. You have to show the data beutifully to the user in a detailed way point wise. Dont give any "## ✅ How to Proceed" or "**Tip:** like paragraph just the jobs data."""
)

# %% [markdown]
# ### Agent 4

# %%
ats_scoring_agent = AssistantAgent(
    name="ATS_Scoring_Agent",
    model_client= model_client,
    system_message = """
You are an ATS (Applicant Tracking System) Scoring Agent.

Task:
- Given a parsed resume (JSON) and a list of multiple parsed job descriptions (JSON), calculate ONE overall ATS score representing the candidate’s average fit across all provided roles.

Scoring Method:
1. Compare the resume to each job description using the following categories:
   - Skills Match: 30%
   - Experience Relevance: 25%
   - Education Alignment: 15%
   - Format & Structure: 15%
   - Keyword Optimization: 15%
2. For each category, average the category scores across all jobs.
3. Apply the category weights to the averaged category scores to compute a final weighted total score.
4. This must produce a single overall ATS score for all jobs combined.

Consistency Rules:
- The same resume and job descriptions should always produce the same score (deterministic).
- No randomness or subjective guessing.
- If a category is missing data (e.g., job has no education requirement), base the score only on available information and note it in reasoning.

Benchmark Comparison:
- 85–100: Excellent fit
- 70–84: Good fit
- 50–69: Average fit
- Below 50: Poor fit

Confidence Intervals:
- Confidence is lower if job descriptions vary greatly or have missing details.
- Provide ± percentage confidence interval.

Output:
Return only valid JSON:

{
  "total_score": <integer>,
  "category_scores": {
    "skills_match": <integer>,
    "experience_relevance": <integer>,
    "education_alignment": <integer>,
    "format_structure": <integer>,
    "keyword_optimization": <integer>
  },
  "weighted_breakdown": {
    "skills_match_weighted": <float>,
    "experience_relevance_weighted": <float>,
    "education_alignment_weighted": <float>,
    "format_structure_weighted": <float>,
    "keyword_optimization_weighted": <float>
  },
  "benchmark_comparison": "<string>",
  "confidence_interval": "+/-<integer>%",
  "reasoning": {
    "skills_match": "<explanation>",
    "experience_relevance": "<explanation>",
    "education_alignment": "<explanation>",
    "format_structure": "<explanation>",
    "keyword_optimization": "<explanation>"
  }
}

Guidelines:
- Only use the provided resume and job descriptions.
- Average scores across jobs first, then apply weights.
- The sum of weighted scores must equal the total_score.
"""

)

# %% [markdown]
# ### Agent 5

# %%
assistant = AssistantAgent(
    name = "assistants",
    model_client= groq_client,
    memory = [mem0_memory],
    system_message="""You are a Visualization Agent in an ATS scoring system. Your responsibilities are:

Task Overview:
Retrieve and Compare Data
   - Receive ATS scoring data from user input.
   - Retrieve corresponding industry benchmarks from memory.
"""
)

# %% [markdown]
# ### Agent 6

# %%
visualization_agent = AssistantAgent(
    name="Visualizer_Agent",
    model_client=groq_client,
    system_message="""
    Task Instructions:

    1. You will receive the required data from the previous agent.
       feed the data in the python code below.
    2. Dont try to write any other than the code given below just fill the values and give it further to next agent. 

   ```python
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ------------------------------------------------------------------
# 1. Data placeholders (Agent should replace with actual values)
# ------------------------------------------------------------------
user_scores = {
    "total_score": <TOTAL_SCORE>,  # e.g., 82
    "category_scores": {
        "skills_match": <SKILLS_MATCH_SCORE>,                # e.g., 62
        "experience_relevance": <EXPERIENCE_RELEVANCE_SCORE>, # e.g., 100
        "education_alignment": <EDUCATION_ALIGNMENT_SCORE>,   # e.g., 100
        "format_structure": <FORMAT_STRUCTURE_SCORE>,         # e.g., 95
        "keyword_optimization": <KEYWORD_OPTIMIZATION_SCORE>  # e.g., 62
    },
    "weighted_breakdown": {
        "skills_match_weighted": <SKILLS_MATCH_WEIGHTED>,                # e.g., 19.0
        "experience_relevance_weighted": <EXPERIENCE_RELEVANCE_WEIGHTED>, # e.g., 25.0
        "education_alignment_weighted": <EDUCATION_ALIGNMENT_WEIGHTED>,   # e.g., 15.0
        "format_structure_weighted": <FORMAT_STRUCTURE_WEIGHTED>,         # e.g., 14.0
        "keyword_optimization_weighted": <KEYWORD_OPTIMIZATION_WEIGHTED>  # e.g., 9.0
    }
}

# Industry benchmarks placeholders
industry_benchmarks = {
    "skills_match": <BENCHMARK_SKILLS_MATCH>,              
    "experience_relevance": <BENCHMARK_EXPERIENCE_RELEVANCE>,
    "education_alignment": <BENCHMARK_EDUCATION_ALIGNMENT>, 
    "keyword_optimization": <BENCHMARK_KEYWORD_OPTIMIZATION>
}

# ------------------------------------------------------------------
# 2. Create a single figure with 3 subplots
# ------------------------------------------------------------------
fig = plt.figure(figsize=(15, 5))
sns.set_style("whitegrid")

# ---------------------- Bar Chart ----------------------
ax1 = fig.add_subplot(1, 3, 1)
categories = [
    "skills_match",
    "experience_relevance",
    "education_alignment",
    "keyword_optimization"
]

candidate_vals = [user_scores["category_scores"][c] for c in categories]
benchmark_vals = [industry_benchmarks[c] for c in categories]

bar_width = 0.35
x = np.arange(len(categories))
ax1.bar(x - bar_width/2, candidate_vals, width=bar_width, label="Candidate", color="#4c72b0")
ax1.bar(x + bar_width/2, benchmark_vals, width=bar_width, label="Industry Benchmark", color="#c44e52")
ax1.set_xticks(x)
ax1.set_xticklabels([c.replace('_', ' ').title() for c in categories], rotation=45, ha="right")
ax1.set_ylabel("Score (%)")
ax1.set_title("Candidate vs. Industry Benchmarks")
ax1.set_ylim(0, 110)
ax1.legend()

# ---------------------- Pie Chart ----------------------
ax2 = fig.add_subplot(1, 3, 2)
labels = [
    "Skills Match",
    "Experience Relevance",
    "Education Alignment",
    "Format & Structure",
    "Keyword Optimization"
]
weights = [
    user_scores["weighted_breakdown"]["skills_match_weighted"],
    user_scores["weighted_breakdown"]["experience_relevance_weighted"],
    user_scores["weighted_breakdown"]["education_alignment_weighted"],
    user_scores["weighted_breakdown"]["format_structure_weighted"],
    user_scores["weighted_breakdown"]["keyword_optimization_weighted"]
]
ax2.pie(weights, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
ax2.set_title("Weighted Score Contribution")

# ---------------------- Radar Chart ----------------------
ax3 = fig.add_subplot(1, 3, 3, polar=True)
radar_labels = [
    "Skills Match",
    "Experience Relevance",
    "Education Alignment",
    "Format & Structure",
    "Keyword Optimization"
]
radar_vals = [
    user_scores["category_scores"]["skills_match"],
    user_scores["category_scores"]["experience_relevance"],
    user_scores["category_scores"]["education_alignment"],
    user_scores["category_scores"]["format_structure"],
    user_scores["category_scores"]["keyword_optimization"]
]
values = radar_vals + [radar_vals[0]]
angles = np.linspace(0, 2 * np.pi, len(radar_labels), endpoint=False).tolist()
angles += angles[:1]
ax3.plot(angles, values, 'o-', linewidth=2, color="#1f77b4", label="Candidate")
ax3.fill(angles, values, color="#1f77b4", alpha=0.15)
ax3.set_thetagrids(np.degrees(angles[:-1]), radar_labels)
ax3.set_ylim(0, 110)
ax3.set_title("Performance Radar")
ax3.grid(True)

plt.tight_layout()
plt.savefig("combined_charts.png", dpi=300)
plt.close()

print("Combined chart saved as combined_charts.png")

```
    """
)

# %% [markdown]
# ### Agent 7

# %%
from autogen_agentchat.agents import CodeExecutorAgent
code_executor_agent = CodeExecutorAgent(
    name="Code_Executor_Agent",
    code_executor=docker
)

# %%
from autogen_agentchat.agents import SocietyOfMindAgent
inner_team = RoundRobinGroupChat(participants=[visualization_agent,code_executor_agent],termination_condition=TextMentionTermination("STOP"),max_turns = 2)
society_of_mind_agent = SocietyOfMindAgent(name="Sociey_of_mind_agent",team=inner_team,model_client=model_client)

# %%
final_team = RoundRobinGroupChat(
    participants=[extracted_text_json,job_description_agent,ats_scoring_agent,improvement_recommendation,assistant,visualization_agent,code_executor_agent,summary_agent],
    termination_condition=TextMentionTermination("STOP"),
    max_turns = 10
)
task = """
'John Doe\nEmail: john.doe@example.com\nPhone: +1 987 654 3210\n\nProfessional Summary:\nHighly motivated software engineer with 4 years of experience in backend and cloud technologies.\n\nSkills:\nPython, SQL, Java, Machine Learning, AWS, Docker, Kubernetes\n\nExperience:\nSoftware Engineer - ABC Tech (2018 - 2020)\nSenior Software Engineer - XYZ Solutions (2020 - Present)\n\nEducation:\nB.Tech Computer Science - University of Example (2014 - 2018)\n\nCertifications:\nAWS Certified Developer'
"""

async for message in final_team.run_stream(task=task):
            if isinstance(message, TextMessage):
                msg = f"{message.source}: {message.content}"
                print(msg)
# task = """
# 'John Doe\nEmail: john.doe@example.com\nPhone: +1 987 654 3210\n\nProfessional Summary:\nHighly motivated software engineer with 4 years of experience in backend and cloud technologies.\n\nSkills:\nPython, SQL, Java, Machine Learning, AWS, Docker, Kubernetes\n\nExperience:\nSoftware Engineer - ABC Tech (2018 - 2020)\nSenior Software Engineer - XYZ Solutions (2020 - Present)\n\nEducation:\nB.Tech Computer Science - University of Example (2014 - 2018)\n\nCertifications:\nAWS Certified Developer'
# """
#     result = await Console(final_team.run_stream(task=TextMessage(content=task,source="user")))
#     last_message = result.messages[-1].content
#     if extracted_text_json.name:
#         save_resume_to_db(conn_online_db,last_message)
#         print("Sended to db")
#     elif job_description_agent.name:
#         save_jobs_to_db(last_message,conn_online_db,resume_id)
#         print("Sended to db")
#     elif ats_scoring_agent.name:
#         send_ats_score(last_message,conn_online_db,resume_id)
#         print("Sended to db")
#     elif improvement_recommendation.name:
#         send_improve_to_score(last_message,conn_online_db,resume_id)
#         print("Sended to db")
# Out:
# user:
# 'John Doe
# Email: john.doe@example.com
# Phone: +1 987 654 3210
#
# Professional Summary:
# Highly motivated software engineer with 4 years of experience in backend and cloud technologies.
#
# Skills:
# Python, SQL, Java, Machine Learning, AWS, Docker, Kubernetes
#
# Experience:
# Software Engineer - ABC Tech (2018 - 2020)
# Senior Software Engineer - XYZ Solutions (2020 - Present)
#
# Education:
# B.Tech Computer Science - University of Example (2014 - 2018)
#
# Certifications:
# AWS Certified Developer'
#
# json_extractor: {"file_type":null,"name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}
# Job_Description_Agent: {
#   "jobs": [
#     {
#       "role": "Senior Java Backend Engineer - Generative AI Platform",
#       "company": "Grid Dynamics",
#       "location": "India",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Develop and maintain scalable backend services for generative AI using Java, Spring Boot, REST APIs, and micro‑services. Requires experience with Spring Security, Spring Data JPA, PostgreSQL/MongoDB/Redis, and message queuing (Kafka, RabbitMQ). Must have Docker, Kubernetes, CI/CD, and cloud platform (AWS/Azure/GCP) experience. Candidate’s Java, AWS, Docker, Kubernetes, and Machine‑Learning background align well.",
#       "job_apply_link": "https://in.indeed.com/viewjob?jk=4eadec35ac636984"
#     },
#     {
#       "role": "Java Backend Engineer",
#       "company": "Maersk",
#       "location": "India",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Design and develop Java backend systems using Spring Boot, Hibernate, and Kafka. Requires strong Java 8+ knowledge, micro‑service architecture, REST APIs, and cloud experience (Azure). Experience with Docker, Kubernetes, and PostgreSQL is preferred. Candidate’s Java, AWS, Docker, Kubernetes and cloud background make this a strong fit.",
#       "job_apply_link": "https://www.maersk.com/careers/vacancies/Java-Backend-Engineer_R156102"
#     },
#     {
#       "role": "Java Backend Dev",
#       "company": "Virtusa",
#       "location": "India",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Design, develop, and test Java applications using REST, SOAP, micro‑services, Spring Boot, and Swagger. Requires solid SQL, Docker, Kubernetes, and CI/CD experience. Candidate’s Java, AWS, Docker, Kubernetes, and SQL skills match the core requirements.",
#       "job_apply_link": "https://www.shine.com/jobs/java-backend-dev/virtusa"
#     },
#     {
#       "role": "Backend‑Java Full‑stack Developer",
#       "company": "Kyndryl India",
#       "location": "India",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Develop cloud‑native Java applications using micro‑service patterns, AWS, Docker, and Kubernetes. Requires 7+ years experience, but candidate’s 4‑year senior experience in similar technologies can be positioned as a close fit. Emphasis on CI/CD, container orchestration, and cloud‑native design matches the candidate’s skill set.",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/backend-java-fullsatck-developer-at-kyndryl-india"
#     },
#     {
#       "role": "Senior Java Backend Engineer - Generative AI Platform",
#       "company": "Visa",
#       "location": "India",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Senior engineering role requiring 10+ years Java backend development, Spring Boot, micro‑services, Kubernetes, and AI/ML integration. While the candidate lacks the senior‑level years, the match on core technologies (Java, Spring Boot, Docker, Kubernetes, cloud) is strong; the role can be considered for senior‑associate or lead‑track positions.",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/sr-manager-sw-engineering-java-backend-spring-boot-microservices-at-visa"
#     }
#   ]
# }
# ATS_Scoring_Agent: {
#   "total_score": 76,
#   "category_scores": {
#     "skills_match": 55,
#     "experience_relevance": 85,
#     "education_alignment": 100,
#     "format_structure": 95,
#     "keyword_optimization": 60
#   },
#   "weighted_breakdown": {
#     "skills_match_weighted": 16.5,
#     "experience_relevance_weighted": 21.25,
#     "education_alignment_weighted": 15,
#     "format_structure_weighted": 14.25,
#     "keyword_optimization_weighted": 9
#   },
#   "benchmark_comparison": "Good fit",
#   "confidence_interval": "+/-5%",
#   "reasoning": {
#     "skills_match": "The résumé contains 7 of the 13 core technical skills required across the five roles, giving a 55% match when averaged over all listings.",
#     "experience_relevance": "Candidate’s 4 years of senior‑level software engineering experience aligns strongly with the 3–10 year expectations of most positions, resulting in an average 85% relevance score.",
#     "education_alignment": "A B.Tech in Computer Science satisfies all bachelor‑level or equivalent degree requirements for each job, yielding 100% alignment.",
#     "format_structure": "The résumé follows a clean, sectioned layout with clear headings and bullet points, meeting ATS formatting standards—estimated 95% score.",
#     "keyword_optimization": "While the résumé covers core technologies, it lacks several role‑specific keywords (e.g., Spring Boot, Kafka, CI/CD). Averaged across the five roles, it achieves a 60% keyword optimization score."
#   }
# }
# Improvement_Agent: ```json
# {
#   "keyword_match": [
#     "Add 'Spring Boot' to the skills list to align with backend development requirements.",
#     "Include 'Spring Security' and 'Spring Data JPA' to demonstrate full‑stack framework knowledge.",
#     "Mention 'Kafka', 'RabbitMQ', or 'Azure Service Bus' to show message‑queuing expertise.",
#     "Add 'PostgreSQL', 'MongoDB', or 'Redis' to the database skill set.",
#     "Include 'Hibernate' to highlight ORM capabilities.",
#     "Add 'RESTful APIs', 'Swagger/OpenAPI', and 'SOAP' to indicate API design experience.",
#     "Insert 'CI/CD' tools such as Jenkins, GitLab CI, or GitHub Actions to showcase pipeline automation.",
#     "Mention cloud‑platform specific names like 'Azure', 'GCP', or 'AWS Lambda' for broader cloud familiarity.",
#     "Add 'Micro‑services Architecture' and 'Microservice patterns' keywords to reflect architectural experience."
#   ],
#   "skill_gap_analysis": [
#     "Enroll in a Spring Boot certification or complete a hands‑on Spring Boot bootcamp to strengthen framework expertise.",
#     "Acquire practical knowledge of Kafka or RabbitMQ via an online course or lab project.",
#     "Learn PostgreSQL or MongoDB through a project that implements CRUD operations with JPA/Hibernate.",
#     "Get familiar with Redis caching by building a caching layer in a micro‑service.",
#     "Complete a CI/CD pipeline workshop using Jenkins or GitLab CI to demonstrate automation skills.",
#     "Add a brief description of experience with Azure services (e.g., Azure Service Bus, Azure Functions) if applicable.",
#     "Consider obtaining an Azure/AWS certification focused on infrastructure as code or DevOps."
#   ],
#   "format_structure_recommendations": [
#     "Add a dedicated 'Technical Skills' section listing categories: Programming Languages, Frameworks, Databases, Message Queues, Cloud Platforms, DevOps tools.",
#     "Place the 'Technical Skills' section immediately after the Professional Summary for early keyword exposure.",
#     "For each role, begin bullet points with action verbs and quantify outcomes (e.g., throughput, latency, cost savings).",
#     "Avoid multi‑column layouts; use a single‑column, left‑aligned text for better ATS parsing.",
#     "Use simple bullet symbols (• or –) instead of images or icons."
#   ],
#   "content_optimization": [
#     "Revise the 'Experience' bullets to reflect key role‑specific tasks, e.g.:",
#     "• Designed and deployed 5 micro‑services using Spring Boot and Docker, achieving 99.9% uptime across 3 availability zones.",
#     "• Implemented Kafka message streams to process 10,000+ events per second, reducing downstream latency by 30 %.",
#     "• Configured CI/CD pipelines with Jenkins and Docker Compose, cutting release cycle time from 48 hrs to 12 hrs.",
#     "• Integrated Spring Security OAuth2 to secure APIs, preventing unauthorized access.",
#     "• Managed PostgreSQL and Redis caching layers, improving data retrieval times by 45 %."
#   ]
# }
# ```
#
# assistants: **Step 1 – Plan**
#
# 1. **Extract the ATS data** – we already have the candidate’s scores and the industry benchmarks (Engineering benchmarks for Skills Match, Keyword Optimisation, and Tech benchmark for Experience Relevance).
# 2. **Create three visualisations**:
#    * Bar chart comparing user scores with benchmarks.
#    * Pie chart showing the weighted score contributions.
#    * Radar chart illustrating performance across all categories.
# 3. **Combine them** into a single 2 × 2 grid, save the figure as `combine_chart.png`, and print *“Charts generated”*.
# 4. **Wrap the plotting code in a string** and write it to a Python script (`solution.py`) following the provided template.
#
# **Step 2 – Python code**
#
# ```python
# code = '''
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # --- Data ---------------------------------------------------------------
# # Category labels
# categories = ['Skills Match', 'Keyword Optimization', 'Experience Relevance']
#
# # Candidate ATS scores
# user_scores = [55, 60, 85]
# # Industry benchmarks
# benchmarks  = [82, 78, 90]
#
# # Weighted contributions (from ATS report)
# weighted_breakdown = {
#     'skills_match_weighted':      16.5,
#     'experience_relevance_weighted': 21.25,
#     'education_alignment_weighted': 15.0,
#     'format_structure_weighted':  14.25,
#     'keyword_optimization_weighted': 9.0
# }
# pie_labels   = list(weighted_breakdown.keys())
# pie_values   = list(weighted_breakdown.values())
#
# # Radar data
# radar_labels = ['Skills Match', 'Keyword Optimization',
#                 'Experience Relevance', 'Education Alignment',
#                 'Format Structure']
# radar_user   = [55, 60, 85, 100, 95]          # User scores
# radar_user.append(radar_user[0])                # Close the polygon
#
# # --- Plotting -----------------------------------------------------------
# fig, axes = plt.subplots(2, 2, figsize=(12, 12))
#
# # 1. Bar chart: User vs Benchmark
# ax = axes[0, 0]
# x = np.arange(len(categories))
# width = 0.35
# ax.bar(x - width/2, user_scores, width, label='User', color='skyblue')
# ax.bar(x + width/2, benchmarks, width, label='Benchmark', color='lightcoral')
# ax.set_xticks(x)
# ax.set_xticklabels(categories)
# ax.set_ylabel('Score (%)')
# ax.set_title('User vs. Industry Benchmark')
# ax.legend()
# ax.grid(axis='y', linestyle='--', alpha=0.5)
#
# # 2. Pie chart: Weighted score contributions
# ax = axes[0, 1]
# ax.pie(pie_values, labels=pie_labels, autopct='%1.1f%%', startangle=140,
#        colors=sns.color_palette('pastel'))
# ax.set_title('Weighted Score Contributions')
#
# # 3. Radar chart: Category performance
# angles = np.linspace(0, 2*np.pi, len(radar_labels), endpoint=False).tolist()
# angles += angles[:1]
# ax = plt.subplot(2, 2, 3, polar=True)
# ax.plot(angles, radar_user, color='navy', linewidth=2, marker='o')
# ax.fill(angles, radar_user, color='navy', alpha=0.25)
# ax.set_thetagrids(np.degrees(angles[:-1]), radar_labels)
# ax.set_title('Radar Chart of Performance')
# ax.set_yticklabels([])  # hide radial grid labels
#
# # 4. Hide unused subplot
# axes[1, 1].axis('off')
#
# plt.tight_layout()
# plt.savefig('combine_chart.png', dpi=300)
# print("Charts generated")
# '''
#
# # Write the plotting script to a file
# with open('solution.py', 'w') as f:
#     f.write(code)
#     print("Code saved successfully in solution.py")
# '''
# ```
#
# This script creates `combine_chart.png` in the current directory and prints **“Charts generated”** when run.
# Visulizer_Agent: ```python
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # --- Data ---------------------------------------------------------------
# # Category labels
# categories = ['Skills Match', 'Keyword Optimization', 'Experience Relevance']
#
# # Candidate ATS scores
# user_scores = [55, 60, 85]
# # Industry benchmarks
# benchmarks  = [82, 78, 90]
#
# # Weighted contributions (from ATS report)
# weighted_breakdown = {
#     'skills_match_weighted':      16.5,
#     'experience_relevance_weighted': 21.25,
#     'education_alignment_weighted': 15.0,
#     'format_structure_weighted':  14.25,
#     'keyword_optimization_weighted': 9.0
# }
# pie_labels   = list(weighted_breakdown.keys())
# pie_values   = list(weighted_breakdown.values())
#
# # Radar data
# radar_labels = ['Skills Match', 'Keyword Optimization',
#                 'Experience Relevance', 'Education Alignment',
#                 'Format Structure']
# radar_user   = [55, 60, 85, 100, 95]          # User scores
# radar_user.append(radar_user[0])                # Close the polygon
#
# # --- Plotting -----------------------------------------------------------
# fig, axes = plt.subplots(2, 2, figsize=(12, 12))
#
# # 1. Bar chart: User vs Benchmark
# ax = axes[0, 0]
# x = np.arange(len(categories))
# width = 0.35
# ax.bar(x - width/2, user_scores, width, label='User', color='skyblue')
# ax.bar(x + width/2, benchmarks, width, label='Benchmark', color='lightcoral')
# ax.set_xticks(x)
# ax.set_xticklabels(categories)
# ax.set_ylabel('Score (%)')
# ax.set_title('User vs. Industry Benchmark')
# ax.legend()
# ax.grid(axis='y', linestyle='--', alpha=0.5)
#
# # 2. Pie chart: Weighted score contributions
# ax = axes[0, 1]
# ax.pie(pie_values, labels=pie_labels, autopct='%1.1f%%', startangle=140,
#        colors=sns.color_palette('pastel'))
# ax.set_title('Weighted Score Contributions')
#
# # 3. Radar chart: Category performance
# angles = np.linspace(0, 2*np.pi, len(radar_labels), endpoint=False).tolist()
# angles += angles[:1]
# ax = plt.subplot(2, 2, 3, polar=True)
# ax.plot(angles, radar_user, color='navy', linewidth=2, marker='o')
# ax.fill(angles, radar_user, color='navy', alpha=0.25)
# ax.set_thetagrids(np.degrees(angles[:-1]), radar_labels)
# ax.set_title('Radar Chart of Performance')
# ax.set_yticklabels([])  # hide radial grid labels
#
# # 4. Hide unused subplot
# axes[1, 1].axis('off')
#
# plt.tight_layout()
# plt.savefig('combine_chart.png', dpi=300)
# print("Charts generated")
# ```
# Code_Executor_Agent: The script ran, then exited with an error (POSIX exit code: 1)
# Its output was:
#   File "/workspace/tmp_code_c2f58117ebf15614e1bc9e19abf3087eb4e29f049bba6dd4a1e1e921dffac0c8.python", line 77
#     '''
#     ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 77)
#
# summarizer_agent: Below is a clean, executable script that reproduces the four‑panel chart and **does not** contain the stray triple‑quoted string that caused the `SyntaxError`.
# Just copy the code into a new file (e.g. `visualizer.py`) and run it.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # ---------- Data ---------------------------------------------------------
# # 1. Category scores
# categories = ['Skills Match', 'Keyword Optimization', 'Experience Relevance']
#
# # Candidate ATS scores
# user_scores = [55, 60, 85]
# # Industry benchmarks (average across similar roles)
# benchmarks  = [82, 78, 90]
#
# # 2. Weighted contribution breakdown
# weighted_breakdown = {
#     'skills_match_weighted':         16.5,
#     'experience_relevance_weighted': 21.25,
#     'education_alignment_weighted':   15.0,
#     'format_structure_weighted':     14.25,
#     'keyword_optimization_weighted': 9.0
# }
# pie_labels   = list(weighted_breakdown.keys())
# pie_values   = list(weighted_breakdown.values())
#
# # 3. Radar chart data
# radar_labels = [
#     'Skills Match',
#     'Keyword Optimization',
#     'Experience Relevance',
#     'Education Alignment',
#     'Format Structure'
# ]
# radar_user   = [55, 60, 85, 100, 95]          # User scores
# radar_user.append(radar_user[0])                 # Close polygon
#
# # ---------- Plotting -------------------------------------------------------
# fig, axes = plt.subplots(2, 2, figsize=(12, 12))
#
# # 1. Bar chart: User vs Benchmark
# ax = axes[0, 0]
# x = np.arange(len(categories))
# width = 0.35
# ax.bar(x - width/2, user_scores, width, label='User', color='skyblue')
# ax.bar(x + width/2, benchmarks, width, label='Benchmark', color='lightcoral')
# ax.set_xticks(x)
# ax.set_xticklabels(categories)
# ax.set_ylabel('Score (%)')
# ax.set_title('User vs. Industry Benchmark')
# ax.legend()
# ax.grid(axis='y', linestyle='--', alpha=0.5)
#
# # 2. Pie chart: Weighted Score Contributions
# ax = axes[0, 1]
# ax.pie(pie_values, labels=pie_labels, autopct='%1.1f%%', startangle=140,
#        colors=sns.color_palette('pastel'))
# ax.set_title('Weighted Score Contributions')
#
# # 3. Radar chart: Category Performance
# angles = np.linspace(0, 2*np.pi, len(radar_labels), endpoint=False).tolist()
# angles += angles[:1]
# ax = plt.subplot(2, 2, 3, polar=True)
# ax.plot(angles, radar_user, color='navy', linewidth=2, marker='o')
# ax.fill(angles, radar_user, color='navy', alpha=0.25)
# ax.set_thetagrids(np.degrees(angles[:-1]), radar_labels)
# ax.set_title('Radar Chart of Performance')
# ax.set_yticklabels([])  # hide radial grid labels
#
# # 4. Hide unused subplot
# axes[1, 1].axis('off')
#
# # ---------- Save & Display ------------------------------------------------
# plt.tight_layout()
# plt.savefig('combine_chart.png', dpi=300)
# print("Charts generated and saved as combine_chart.png")
# ```
#
# **How to run**
#
# ```bash
# # 1. Save the code above to visualizer.py
# # 2. Ensure you have the required packages:
# pip install numpy matplotlib seaborn
# # 3. Run the script:
# python visualizer.py
# ```
#
# The script will create `combine_chart.png` in the current directory. No syntax errors will occur.
# json_extractor: {"file_type":null,"name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}
# ERROR:autogen_core:Error processing publish message for Job_Description_Agent_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 67, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 485, in on_message_impl
#     return await h(self, message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 268, in wrapper
#     return_value = await func(self, message, ctx)  # type: ignore
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 133, in handle_request
#     async for msg in self._agent.on_messages_stream(self._message_buffer, ctx.cancellation_token):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\agents\_assistant_agent.py", line 989, in on_messages_stream
#     async for output_event in self._process_model_result(
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\agents\_assistant_agent.py", line 1299, in _process_model_result
#     async for reflection_response in cls._reflect_on_tool_use_flow(
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\agents\_assistant_agent.py", line 1454, in _reflect_on_tool_use_flow
#     raise RuntimeError("Reflect on tool use produced no valid text response.")
# RuntimeError: Reflect on tool use produced no valid text response.
# ERROR:autogen_core:Error processing publish message for json_extractor_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 72, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 486, in on_message_impl
#     return await self.on_unhandled_message(message, ctx)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 195, in on_unhandled_message
#     raise ValueError(f"Unhandled message in agent container: {type(message)}")
# ValueError: Unhandled message in agent container: <class 'autogen_agentchat.teams._group_chat._events.GroupChatError'>
# ERROR:autogen_core:Error processing publish message for ATS_Scoring_Agent_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 72, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 486, in on_message_impl
#     return await self.on_unhandled_message(message, ctx)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 195, in on_unhandled_message
#     raise ValueError(f"Unhandled message in agent container: {type(message)}")
# ValueError: Unhandled message in agent container: <class 'autogen_agentchat.teams._group_chat._events.GroupChatError'>
# ERROR:autogen_core:Error processing publish message for Improvement_Agent_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 72, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 486, in on_message_impl
#     return await self.on_unhandled_message(message, ctx)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 195, in on_unhandled_message
#     raise ValueError(f"Unhandled message in agent container: {type(message)}")
# ValueError: Unhandled message in agent container: <class 'autogen_agentchat.teams._group_chat._events.GroupChatError'>
# ERROR:autogen_core:Error processing publish message for assistants_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 72, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 486, in on_message_impl
#     return await self.on_unhandled_message(message, ctx)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 195, in on_unhandled_message
#     raise ValueError(f"Unhandled message in agent container: {type(message)}")
# ValueError: Unhandled message in agent container: <class 'autogen_agentchat.teams._group_chat._events.GroupChatError'>
# ERROR:autogen_core:Error processing publish message for Visulizer_Agent_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 72, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 486, in on_message_impl
#     return await self.on_unhandled_message(message, ctx)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 195, in on_unhandled_message
#     raise ValueError(f"Unhandled message in agent container: {type(message)}")
# ValueError: Unhandled message in agent container: <class 'autogen_agentchat.teams._group_chat._events.GroupChatError'>
# ERROR:autogen_core:Error processing publish message for Code_Executor_Agent_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 72, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 486, in on_message_impl
#     return await self.on_unhandled_message(message, ctx)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 195, in on_unhandled_message
#     raise ValueError(f"Unhandled message in agent container: {type(message)}")
# ValueError: Unhandled message in agent container: <class 'autogen_agentchat.teams._group_chat._events.GroupChatError'>
# ERROR:autogen_core:Error processing publish message for summarizer_agent_87a21c5d-7340-4888-9d5d-78f24cc0c8ec/87a21c5d-7340-4888-9d5d-78f24cc0c8ec
# Traceback (most recent call last):
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_single_threaded_agent_runtime.py", line 606, in _on_message
#     return await agent.on_message(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_base_agent.py", line 119, in on_message
#     return await self.on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_sequential_routed_agent.py", line 72, in on_message_impl
#     return await super().on_message_impl(message, ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_core\_routed_agent.py", line 486, in on_message_impl
#     return await self.on_unhandled_message(message, ctx)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 195, in on_unhandled_message
#     raise ValueError(f"Unhandled message in agent container: {type(message)}")
# ValueError: Unhandled message in agent container: <class 'autogen_agentchat.teams._group_chat._events.GroupChatError'>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[90], line 10
#       1 final_team = RoundRobinGroupChat(
#       2     participants=[extracted_text_json,job_description_agent,ats_scoring_agent,improvement_recommendation,assistant,visualization_agent,code_executor_agent,summary_agent],
#       3     termination_condition=TextMentionTermination("STOP"),
#       4     max_turns = 10
#       5 )
#       6 task = """
#       7 'John Doe\nEmail: john.doe@example.com\nPhone: +1 987 654 3210\n\nProfessional Summary:\nHighly motivated software engineer with 4 years of experience in backend and cloud technologies.\n\nSkills:\nPython, SQL, Java, Machine Learning, AWS, Docker, Kubernetes\n\nExperience:\nSoftware Engineer - ABC Tech (2018 - 2020)\nSenior Software Engineer - XYZ Solutions (2020 - Present)\n\nEducation:\nB.Tech Computer Science - University of Example (2014 - 2018)\n\nCertifications:\nAWS Certified Developer'
#       8 """
# ---> 10 async for message in final_team.run_stream(task=task):
#      11             if isinstance(message, TextMessage):
#      12                 msg = f"{message.source}: {message.content}"
#
# File c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_base_group_chat.py:554, in BaseGroupChat.run_stream(self, task, cancellation_token, output_task_messages)
#     550 if isinstance(message, GroupChatTermination):
#     551     # If the message contains an error, we need to raise it here.
#     552     # This will stop the team and propagate the error.
#     553     if message.error is not None:
# --> 554         raise RuntimeError(str(message.error))
#     555     stop_reason = message.message.content
#     556     break
#
# RuntimeError: RuntimeError: Reflect on tool use produced no valid text response.
# Traceback:
# Traceback (most recent call last):
#
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\teams\_group_chat\_chat_agent_container.py", line 133, in handle_request
#     async for msg in self._agent.on_messages_stream(self._message_buffer, ctx.cancellation_token):
#
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\agents\_assistant_agent.py", line 989, in on_messages_stream
#     async for output_event in self._process_model_result(
#
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\agents\_assistant_agent.py", line 1299, in _process_model_result
#     async for reflection_response in cls._reflect_on_tool_use_flow(
#
#   File "c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_agentchat\agents\_assistant_agent.py", line 1454, in _reflect_on_tool_use_flow
#     raise RuntimeError("Reflect on tool use produced no valid text response.")
#
# RuntimeError: Reflect on tool use produced no valid text response.

# %%
await main()
# Out:
# ---------- TextMessage (user) ----------
#
# 'John Doe
# Email: john.doe@example.com
# Phone: +1 987 654 3210
#
# Professional Summary:
# Highly motivated software engineer with 4 years of experience in backend and cloud technologies.
#
# Skills:
# Python, SQL, Java, Machine Learning, AWS, Docker, Kubernetes
#
# Experience:
# Software Engineer - ABC Tech (2018 - 2020)
# Senior Software Engineer - XYZ Solutions (2020 - Present)
#
# Education:
# B.Tech Computer Science - University of Example (2014 - 2018)
#
# Certifications:
# AWS Certified Developer'
# ---------- TextMessage (json_extractor) ----------
# {"file_type":null,"name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}
# ---------- ToolCallRequestEvent (Job_Description_Agent) ----------
# [FunctionCall(id='fc_2ad85afa-b12a-4631-806e-ce14a3a15a60', arguments='{"query":"Python developer"}', name='JobFinder')]
# ---------- ToolCallExecutionEvent (Job_Description_Agent) ----------
# [FunctionExecutionResult(content='[{\'role\': \'Lead Software Engineer - Python\', \'company\': \'EPAM Systems\', \'employment_type\': \'Full–time\', \'job_location\': \'India\', \'job_salary\': \'None - None\', \'job_description\': \'We are seeking a highly experienced Lead Software Engineer with expertise in Python to lead development efforts, influence technical direction, and deliver robust, scalable solutions.\\n\\nThe ideal candidate will bring proven expertise in Python, database systems, and modern software development practices to drive the success of critical projects.\\n\\nResponsibilities\\n• Collaborate with stakeholders to gather requirements, create technical designs, and align solutions with business goals\\n• Lead the development of high-quality, scalable, and maintainable software systems\\n• Conduct technical reviews, including code reviews, to ensure adherence to best practices, coding standards, and performance benchmarks\\n• Coordinate with cross-functional teams to ensure successful implementation of features and solutions\\n• Troubleshoot and resolve complex technical challenges across the development lifecycle\\n• Mentor and guide team members, offering technical leadership and fostering skills development\\n• Drive the adoption of modern development processes and tools, including CI/CD practices through GitHub Actions\\n• Optimize application performance and database queries, ensuring efficiency and scalability\\n• Utilize Agile/Scrum methodologies to manage projects and deliver iterative improvements\\n• Oversee database architecture design and ensure proper integration with applications\\n\\nRequirements\\n• 7-12 years of experience in software development with demonstrated expertise in Python\\n• Proficiency in PostgreSQL and MS SQL Server for database design, optimization, and management\\n• Hands-on expertise with GitHub Actions for automation and CI/CD workflows\\n• Competency in ReactJS for developing interactive, dynamic user interfaces\\n• Solid understanding of Scrum/Agile methodologies for collaborative development and delivery\\n\\nNice to have\\n• Familiarity with other front-end frameworks beyond ReactJS\\n• Skills in optimizing cross-platform application performance\\n• Understanding of advanced DevOps practices and tools\', \'job_apply_link\': \'https://in.linkedin.com/jobs/view/lead-software-engineer-python-at-epam-systems-4282811031?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic\'}, {\'role\': \'Python Developer / Data Analyst - +3 years of experience - Full remote - Contractor in USD\', \'company\': \'All European Careers\', \'employment_type\': \'Contractor\', \'job_location\': \'India\', \'job_salary\': \'None - None\', \'job_description\': \'For an international project in Chennai, we are urgently looking for a Full Remote Data Analyst. The ideal candidate will have good understanding of Data integration, Data cleanup for Knowledge 360 and other related products for knowledge system..\\n\\nWe are looking for a motivated contractor. Candidates need to be fluent in English.\\n\\nTasks and responsibilities:\\n\\nDesign and implement cloud-based solutions using Azure and Google Cloud platforms. Automate data pipelines to facilitate efficient data flow and processing;\\n\\nDevelop and manage data pipelines using technologies like PySpark and Databricks;\\n\\nEnsure the scalability and reliability of data processing workflows;\\n\\nWork with Large Language Models (LLMs) such as GPT and OpenAI models to enhance applications with natural language processing (NLP) capabilities;\\n\\nDesign and implement prompt engineering strategies to optimize model performance in business applications;\\n\\nTrain, fine-tune, and deploy AI models, analyzing their performance based on real-world results;\\n\\nOptimize models using feedback mechanisms to improve efficiency;\\n\\nUtilize strong communication skills to convey complex technical concepts to non-technical stakeho ...
# ---------- TextMessage (Job_Description_Agent) ----------
# {
#   "jobs": [
#     {
#       "role": "Python Developer / Data Analyst - +3 years of experience - Full remote - Contractor in USD",
#       "company": "All European Careers",
#       "location": "India (Remote)",
#       "employment_type": "Contractor",
#       "salary": "Not disclosed",
#       "job_description": "Develop and automate cloud‑based data pipelines on Azure/Google Cloud using Python, PySpark, and Databricks. Build and manage data pipelines, work with LLMs (GPT/OpenAI) for NLP, perform prompt engineering, train and fine‑tune AI models, and optimize model performance. Requires 3+ years Python, cloud, and ML experience; AWS certification is a plus.",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/python-developer-data-analyst-%2B3-years-of-experience-full-remote-contractor-in-usd-at-all-european-careers-4283543667?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "Python & Machine Learning Developer",
#       "company": "Collateral Medical Private Limited",
#       "location": "India (Mumbai)",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Design and implement AI/ML models for healthcare using Python libraries (NumPy, pandas, scikit‑learn, TensorFlow, PyTorch). Analyze datasets, develop and test models, and collaborate with engineers and data analysts. Emphasis on clean, documented code and reproducibility. Ideal for candidates with Python, ML, and cloud experience (AWS, Docker, Kubernetes).",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/python-machine-learning-developer-in-mumbai-at-collateral-medical-private-limited-4284025021?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "Python Developer/ Golang Developer",
#       "company": "Hireginie",
#       "location": "HSR Layout, Bangalore, India",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Senior backend developer role focusing on Python (and Golang) to build scalable services. Responsibilities include developing APIs, designing data models (PostgreSQL/MongoDB), deploying on AWS, and using Docker and CI/CD pipelines. Requires strong Python, AWS, Docker, and Kubernetes background, matching the candidate’s cloud‑native experience.",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/python-developer-golang-developer-at-hireginie-4282253664?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "Python Developer | 2-3 Years",
#       "company": "Logistic Infotech Pvt Ltd",
#       "location": "Ahmedabad/Rajkot, India",
#       "employment_type": "Full‑time",
#       "salary": "₹25,000 - ₹35,000 per month",
#       "job_description": "Develop, test, and maintain scalable web applications using Python and Django. Build RESTful APIs, work with MySQL/PostgreSQL, and use Git, Docker, and AWS. Requires 2‑3 years of Python experience and familiarity with Docker, CI/CD, and cloud platforms. Aligns with the candidate’s Python, AWS, Docker, and SQL skill set.",
#       "job_apply_link": "https://in.indeed.com/viewjob?jk=0bf46f631e263945&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     },
#     {
#       "role": "Lead Software Engineer - Python",
#       "company": "EPAM Systems",
#       "location": "India",
#       "employment_type": "Full‑time",
#       "salary": "Not disclosed",
#       "job_description": "Lead development of Python‑based systems, overseeing architecture, code reviews, CI/CD (GitHub Actions), database design (PostgreSQL, MS SQL) and mentoring junior engineers. Requires strong Python expertise, database proficiency, and familiarity with Docker and cloud environments (AWS). Suitable for a software engineer with strong Python, SQL, and cloud experience aiming to move into a leadership role.",
#       "job_apply_link": "https://in.linkedin.com/jobs/view/lead-software-engineer-python-at-epam-systems-4282811031?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#     }
#   ]
# }
# ---------- TextMessage (ATS_Scoring_Agent) ----------
# ```json
# {
#   "total_score": 85,
#   "category_scores": {
#     "skills_match": 65,
#     "experience_relevance": 100,
#     "education_alignment": 100,
#     "format_structure": 90,
#     "keyword_optimization": 86
#   },
#   "weighted_breakdown": {
#     "skills_match_weighted": 19.5,
#     "experience_relevance_weighted": 25.0,
#     "education_alignment_weighted": 15.0,
#     "format_structure_weighted": 13.5,
#     "keyword_optimization_weighted": 12.9
#   },
#   "benchmark_comparison": "Excellent fit",
#   "confidence_interval": "+/-10%",
#   "reasoning": {
#     "skills_match": "Across the five job descriptions, the candidate matched 4‑5 of the 6‑9 skills highlighted per role, averaging about 65% of the relevant skill set required.",
#     "experience_relevance": "All positions call for 2‑3+ years of software/ML experience; the candidate’s 5+ years satisfy this requirement, scoring 100%.",
#     "education_alignment": "Each role implies a bachelor’s-level education; the candidate’s B.Tech in Computer Science meets this, yielding 100%.",
#     "format_structure": "The résumé is concise, uses clear headings and bullet points, and follows ATS best practices, consistently scoring 90% across roles.",
#     "keyword_optimization": "Key terms such as Python, ML, AWS, Docker, and Kubernetes appear for most roles, averaging 86% keyword match."
#   }
# }
# ```
# ---------- TextMessage (json_extractor) ----------
# {"file_type":null,"name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}
# ---------- TextMessage (Job_Description_Agent) ----------
# {
#   "resume_improvement_recommendations": {
#     "overall_score_target": 95,
#     "actions_by_category": {
#       "skills_match": {
#         "current_score": 65,
#         "target_score": 80,
#         "recommendations": [
#           "Add **Docker Compose**, **Kubernetes Helm**, or **Terraform** to highlight deeper cloud‑native orchestration experience.",
#           "Include specific **ML frameworks** such as TensorFlow, PyTorch, or scikit‑learn in the skills section.",
#           "Add **CI/CD** tools (e.g., GitHub Actions, Jenkins) to align with roles that emphasize pipeline automation."
#         ]
#       },
#       "experience_relevance": {
#         "current_score": 100,
#         "target_score": 100,
#         "recommendations": [
#           "Add brief bullet points that showcase **MLOps** or **production ML** work to reinforce relevance to ML Ops roles."
#         ]
#       },
#       "education_alignment": {
#         "current_score": 100,
#         "target_score": 100,
#         "recommendations": [
#           "Mention any **relevant coursework** (e.g., Distributed Systems, Cloud Computing) under education to increase keyword hits."
#         ]
#       },
#       "format_structure": {
#         "current_score": 90,
#         "target_score": 95,
#         "recommendations": [
#           "Use a **two‑column layout** (contact on one side, sections on the other) to improve readability for ATS parsers that favor structured formats.",
#           "Add **bullet points** under each experience entry to quantify impact (e.g., “Reduced deployment time by 30% using Docker & Kubernetes”)."
#         ]
#       },
#       "keyword_optimization": {
#         "current_score": 86,
#         "target_score": 95,
#         "recommendations": [
#           "Insert additional **industry‑specific keywords** such as “MLOps”, “Model Deployment”, “Data Pipeline”, “AWS Lambda”, “Sage‑Maker”, “Kubernetes‑Ops”, and “CI/CD”.",
#           "Include the **certification** name in the headline (e.g., “AWS Certified Developer – Cloud & DevOps”) to capture certification keywords."
#         ]
#       }
#     },
#     "overall_action_plan": [
#       "Refresh the professional summary to incorporate top‑ranked keywords (e.g., “Experienced Python developer with 5+ years in cloud‑native backend, MLOps, and scalable ML solutions”).",
#       "Create a separate **Certifications** section with bullet points for each certification and its relevant skills.",
#       "Add a **Projects** section that highlights at least two ML‑focused projects (e.g., model deployment on AWS, Docker‑based microservice for data processing) to boost keyword density."
#     ],
#     "expected_improved_score": {
#       "total_score_estimate": 92,
#       "confidence_interval": "+/-5%"
#     }
#   }
# }
# ---------- TextMessage (ATS_Scoring_Agent) ----------
# ```json
# {
#   "total_score": 92,
#   "category_scores": {
#     "skills_match": 80,
#     "experience_relevance": 100,
#     "education_alignment": 100,
#     "format_structure": 95,
#     "keyword_optimization": 95
#   },
#   "weighted_breakdown": {
#     "skills_match_weighted": 24.0,
#     "experience_relevance_weighted": 25.0,
#     "education_alignment_weighted": 15.0,
#     "format_structure_weighted": 14.0,
#     "keyword_optimization_weighted": 14.0
#   },
#   "benchmark_comparison": "Excellent fit",
#   "confidence_interval": "+/-5%",
#   "reasoning": {
#     "skills_match": "The added skills (Docker Compose, Kubernetes Helm, Terraform, TensorFlow, PyTorch, scikit-learn, GitHub Actions, Jenkins) bring the skills match to 80%, aligning with the top‑ranked keywords in the job postings.",
#     "experience_relevance": "Experience remains fully relevant (5+ years) and the added bullet points on MLOps reinforce the fit, keeping the score at 100%.",
#     "education_alignment": "Including coursework in Distributed Systems and Cloud Computing increases keyword hits but the baseline education score stays at 100%.",
#     "format_structure": "A two‑column layout with quantified bullets improves readability; score improves from 90 to 95%.",
#     "keyword_optimization": "The expanded keyword list (MLOps, Model Deployment, AWS Lambda, Sage‑Maker, Kubernetes‑Ops, CI/CD, etc.) elevates keyword coverage to 95%."
#   }
# }
# ```
# ---------- TextMessage (json_extractor) ----------
# {"file_type":null,"name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes","Docker Compose","Kubernetes Helm","Terraform","TensorFlow","PyTorch","scikit-learn","GitHub Actions","Jenkins"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)","Relevant coursework: Distributed Systems, Cloud Computing"],"certifications":["AWS Certified Developer"]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 await main()
#
# Cell In[70], line 14, in main()
#      12 last_message = result.messages[-1].content
#      13 if extracted_text_json.name:
# ---> 14     save_resume_to_db(conn_online_db,last_message)
#      15     print("Sended to db")
#      16 elif job_description_agent.name:
#
# Cell In[62], line 9, in save_resume_to_db(conn, parsed_string)
#       2 def save_resume_to_db(conn,parsed_string):
#       3     query = """
#       4     INSERT INTO resumes (file_type, raw_text, parsed_json)
#       5     VALUES (%s, %s, %s)
#       6     RETURNING id;
#       7     """
#       8     params = (
# ----> 9         parsed_string['file_type'],
#      10         extracted_text,
#      11         json.dumps(parsed_string),
#      12     )
#      13     try:
#      14         if conn_online_db:
#
# TypeError: string indices must be integers, not 'str'

# %%
extracted_text_json.name
# Out:
# 'json_extractor'

# %%
task = """
'John Doe\nEmail: john.doe@example.com\nPhone: +1 987 654 3210\n\nProfessional Summary:\nHighly motivated software engineer with 4 years of experience in backend and cloud technologies.\n\nSkills:\nPython, SQL, Java, Machine Learning, AWS, Docker, Kubernetes\n\nExperience:\nSoftware Engineer - ABC Tech (2018 - 2020)\nSenior Software Engineer - XYZ Solutions (2020 - Present)\n\nEducation:\nB.Tech Computer Science - University of Example (2014 - 2018)\n\nCertifications:\nAWS Certified Developer'
"""
await Console(final_team.run_stream(task=TextMessage(content=task,source="user")))
# Out:
# ---------- TextMessage (user) ----------
#
# 'John Doe
# Email: john.doe@example.com
# Phone: +1 987 654 3210
#
# Professional Summary:
# Highly motivated software engineer with 4 years of experience in backend and cloud technologies.
#
# Skills:
# Python, SQL, Java, Machine Learning, AWS, Docker, Kubernetes
#
# Experience:
# Software Engineer - ABC Tech (2018 - 2020)
# Senior Software Engineer - XYZ Solutions (2020 - Present)
#
# Education:
# B.Tech Computer Science - University of Example (2014 - 2018)
#
# Certifications:
# AWS Certified Developer'
# c:\Users\mkuma\OneDrive\Desktop\MEOW MEOW 1.0\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:660: DeprecationWarning: Using response_format to specify the BaseModel for structured output type will be deprecated. Use json_output in create and create_stream instead.
#   create_params = self._process_create_args(
# ---------- TextMessage (json_extractor) ----------
# {"file_type":null,"name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}
# ---------- ToolCallRequestEvent (Job_Description_Agent) ----------
# [FunctionCall(id='fc_2cd2c2f6-a20a-490a-9dba-40b118a53d94', arguments='{"query":"software engineer"}', name='JobFinder')]
# ---------- ToolCallExecutionEvent (Job_Description_Agent) ----------
# [FunctionExecutionResult(content='[{\'role\': \'System Software Engineer - Java Runtimes, Tooling and Ecosystem\', \'company\': \'Canonical\', \'employment_type\': \'Full–time\', \'job_location\': \'India\', \'job_salary\': \'None - None\', \'job_description\': "Canonical is a leading provider of open source software and operating systems to the global enterprise and technology markets. Our platform, Ubuntu, is very widely used in breakthrough enterprise initiatives such as public cloud, data science, AI, engineering innovation, and IoT. Our customers include the world\'s leading public cloud and silicon providers, and industry leaders in many sectors. The company is a pioneer of global distributed collaboration, with 1200+ colleagues in 75+ countries and very few office-based roles. Teams meet two to four times yearly in person, in interesting locations around the world, to align on strategy and execution.\\n\\nThe company is founder-led, profitable, and growing.\\n\\nWe are hiring a System Software Engineer for Java Runtimes, tooling, and ecosystem\\n\\nWe are expanding our team focusing on the Java ecosystem. They will deliver the best possible Java runtimes and supporting tooling in Ubuntu, and enable Ubuntu users access to the wider Java ecosystem. Our goal is to enable mission-critical Java applications to be deployed and operated safely, securely and efficiently on large-scale Ubuntu estates. We are also keen to ensure that the cutting edge of Java innovation is available to Ubuntu users, to lay the foundation for future inventions and open source communities building on the JVM.\\n\\nThis is an exciting opportunity for a software engineer passionate about open source software, Java and the Java Virtual Machine, Linux system and software architecture. Come build a rewarding, meaningful career working with the best and brightest people in technology at Canonical, and make Ubuntu the best operating system to develop and run your Java applications in the cloud and in data centers, in containers or directly on the operating system, and anywhere else Java and Ubuntu can run (that is: pretty much everywhere!).\\n\\n25 years in and going strong, Java is a staple of enterprise software the world over. A vibrant ecosystem of programming languages like Kotlin and Clojure has grown around the Java Virtual Machine. The JVM is at the forefront of exploration into how scalable, reliable software is written and run. The ecosystem of frameworks to build applications in Java and other JVM languages is undergoing a revolution centered on GraalVM and native application images thanks to frameworks like Spring Boot Native, Quarkus.io and Micronaut.\\n\\nUbuntu strives to deliver the latest-best free software components, in an easy to use and highly reliable form, with long-term security maintenance commitments. We build on the technical excellence of Debian and bring additional focus and shape to the solutions we offer the industry. The successful applicants will be passionate about the future of Java and the Java Virtual Machine, and of Ubuntu. They will be mindful of the dynamics of the open-source ecosystem, and aware of the needs of large but innovative organizations.\\n\\nPart of the Ubuntu Foundations team, you will work on the architecture, design and development of core components of Canonical Ubuntu related to the Java Virtual Machine and associated tooling. You will discuss design with colleagues and community, and mentor less senior engineers through code reviews and design reviews. You will also work with other teams to ensure our decisions improve the overall performance and experience of Ubuntu. As a member of the Ubuntu Foundations team, your work will have an impact on every aspect of the Ubuntu ecosystem from Desktop to Server, Ubuntu Core, containers and also cloud images.\\n\\nWe believe that developers working with Java and other JVM languages all around the world should have an operating system that makes their job easy ...
# ---------- TextMessage (Job_Description_Agent) ----------
# [
#   {
#     "role": "System Software Engineer - Java Runtimes, Tooling and Ecosystem",
#     "company": "Canonical",
#     "location": "India (Remote - APAC)",
#     "description": "Develop and package Java runtimes and tooling for Ubuntu, work on open source Java ecosystem, Linux system, and cloud technologies.",
#     "apply_link": "https://in.linkedin.com/jobs/view/system-software-engineer-java-runtimes-tooling-and-ecosystem-at-canonical-4284589590?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#   },
#   {
#     "role": "Associate - Software Engineer",
#     "company": "Firstsource Healthcare",
#     "location": "Telangana, India",
#     "description": "Senior software development using Java/J2EE, Spring Boot, AWS, and PostgreSQL; mentor junior engineers and work on cloud‑based solutions.",
#     "apply_link": "https://in.indeed.com/viewjob?jk=ca5b7e6d4d9d50df&utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#   },
#   {
#     "role": "Software Engineer II - Core Platform (DevOps)",
#     "company": "Eventbrite",
#     "location": "Hyderabad, Telangana, India",
#     "description": "Build developer tools and infrastructure for software delivery pipelines; work with Python, Django, AWS, Docker, Kubernetes and CI/CD pipelines.",
#     "apply_link": "https://www.eventbritecareers.com/jobs/software-engineer-ii-core-platform-devops-hyderabad-hyderabad-telangana-india?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#   },
#   {
#     "role": "Staff Software Engineer - Java Full Stack",
#     "company": "Visa",
#     "location": "India",
#     "description": "Design, develop and maintain large‑scale Java services, work with Go, Java, Python, Docker, Kubernetes; lead and mentor teams.",
#     "apply_link": "https://in.linkedin.com/jobs/view/staff-software-engineer-java-full-stack-6-8-yrs-exp-at-visa-4284134793?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#   },
#   {
#     "role": "Software Engineer .NET Full Stack",
#     "company": "Zenoti",
#     "location": "Hyderabad, Telangana, India",
#     "description": "Develop full‑stack web applications using .NET, C#, SQL Server; collaborate with product and QA teams; maintain high‑scale SaaS platform.",
#     "apply_link": "https://in.linkedin.com/jobs/view/software-engineer-net-full-stack-at-zenoti-4283542692?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic"
#   }
# ]
# {
#   "total_score": 78,
#   "category_scores": {
#     "skills_match": 61,
#     "experience_relevance": 90,
#     "education_alignment": 100,
#     "format_structure": 85,
#     "keyword_optimization": 61
#   },
#   "weighted_breakdown": {
#     "skills_match_weighted": 18.3,
#     "experience_relevance_weighted": 22.5,
#     "education_alignment_weighted": 15.0,
#     "format_structure_weighted": 12.75,
#     "keyword_optimization_weighted": 9.15
#   },
#   "benchmark_comparison": "Good fit",
#   "confidence_interval": "+/-10%",
#   "reasoning": {
#     "skills_match": "The candidate’s skills overlap with each job description at an average of 61%, based on the proportion of required keywords (e.g., Java, Python, AWS, Docker, Kubernetes, SQL) present in the resume.",
#     "experience_relevance": "With approximately 7 years of relevant software engineering experience, the candidate exceeds the typical experience required for senior‑level positions across all jobs, yielding a high relevance score of 90%.",
#     "education_alignment": "None of the job descriptions specify education requirements, so there is no mismatch; the score is set to 100% by default.",
#     "format_structure": "The resume contains clear sections (summary, skills, experience, education, certifications) and is well‑structured, giving a solid format score of 85%.",
#     "keyword_optimization": "Keyword presence mirrors the skills match; key terms from the jobs appear in the resume about 61% of the time across all roles."
#   }
# }
# ---------- MemoryQueryEvent (assistants) ----------
# [MemoryContent(content='In Education, the industry standard for keyword optimization is 72%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Education', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 72, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.6383872222419749, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 31, 8658, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 15, 47, 134503, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['misc']}), MemoryContent(content='In Engineering, the industry standard for skills match is 82%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'skills_match', 'industry': 'Engineering', 'common_gaps': ['Missing core frameworks/tools', 'Outdated technical skills', 'No mention of in-demand software'], 'industry_standard': 82, 'optimization_tips': ['List all relevant tools and frameworks', 'Highlight in-demand skills in top sections', 'Align skills with job description wording'], 'score': 0.631785053962024, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 856863, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 0, 880011, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Engineering, the industry standard for keyword optimization is 78%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'keyword_optimization', 'industry': 'Engineering', 'common_gaps': ['Missing primary keywords', 'Keywords concentrated in one section', 'Low keyword density'], 'industry_standard': 78, 'optimization_tips': ['Spread keywords throughout resume', 'Use them naturally in bullet points', 'Add to project descriptions'], 'score': 0.6306259003841195, 'created_at': datetime.datetime(2025, 8, 13, 4, 16, 57, 891488, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 16, 57, 912375, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Education, the industry standard for experience relevance is 80%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'experience_relevance', 'industry': 'Education', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'industry_standard': 80, 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting'], 'score': 0.6281392387110247, 'created_at': datetime.datetime(2025, 8, 13, 4, 15, 7, 20376, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'updated_at': datetime.datetime(2025, 8, 13, 4, 15, 7, 39378, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 'categories': ['professional_details']}), MemoryContent(content='In Tech, the industry standard for experience relevance is 90%.', mime_type='text/plain', metadata={'type': 'best_practice', 'unit': 'percent', 'category': 'experience_relevance', 'industry': 'Tech', 'common_gaps': ['No quantified results', 'Missing role-specific projects', 'Unclear responsibilities'], 'industry_standard': 90, 'optimization_tips': ['Add measurable results to achievements', 'Focus on industry-specific experience', 'Match job titles to posting'], 'score': 0.6106124884255224, 'created_at': datetime.datetime(2025, 8, 13, 4, 10, 51, 129376, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200 ...
# ---------- TextMessage (assistants) ----------
# Below is a side‑by‑side comparison of your ATS‑derived scores against the most relevant industry benchmarks (drawn from our memory database).
# The comparison uses **Tech**‑industry standards where available, otherwise **Engineering** standards, which are most applicable to software‑engineering resumes.
#
# | Category | Your Score | Benchmark (Tech/Eng) | Δ (Your – Benchmark) | Interpretation |
# |---------|-----------|----------------------|---------------------|---------------|
# | **Skills Match** | 61 % | 85 % (Tech) | **‑24 %** | Well below the industry norm for tech‑engineers. |
# | **Experience Relevance** | 90 % | 90 % (Tech) | **0 %** | Meets the benchmark exactly. |
# | **Education Alignment** | 100 % | 92 % (Eng) | **+8 %** | Exceeds the benchmark; no education mismatch. |
# | **Keyword Optimization** | 61 % | 78 % (Engineering) | **‑17 %** | Short on the expected keyword density. |
# | **Format & Structure** | 85 % | – | – | No industry benchmark available; 85 % is solid. |
#
# ### Key Take‑aways
#
# | Category | What the number means | Actionable Advice |
# |---------|---------------------|------------------|
# | **Skills Match** | Only 61 % of the job‑specific keywords appear in your resume. | • List all relevant languages & frameworks (e.g., **Spring Boot, PostgreSQL** for healthcare roles).<br>• Highlight tech‑stack usage in each role (e.g., “Implemented microservices with Spring Boot, PostgreSQL”). |
# | **Experience Relevance** | You’re perfectly matched in terms of years & role seniority. | • Keep this section concise and focused on achievements. |
# | **Education Alignment** | Over‑aligned—your B.Tech matches or exceeds the requirement. | • No change needed. |
# | **Keyword Optimization** | Your résumé’s keyword density is 17 % below benchmark. | • Re‑scan each job description and add missing terms (e.g., **CI/CD, Terraform, GitHub Actions**).<br>• Use the exact phrasing from the job ad (e.g., “Java Runtimes” vs “Java”). |
# | **Format & Structure** | 85 % indicates a clean, readable resume. | • Minor tweaks (e.g., bullet‑point consistency, avoid passive voice). |
#
# ### Confidence Interval
# Your overall confidence interval (+/- 10 %) reflects the variability of ATS scoring; the true score could range **68–88 %**. Improving the lower‑scoring categories (skills match & keyword optimization) will shift this range upward.
#
# ---
#
# #### Quick Fix Checklist
#
# | Item | What to add/modify | Why it matters |
# |------|-------------------|---------------|
# | **Add missing tech keywords** | Insert “Spring Boot”, “PostgreSQL”, “CI/CD”, “Terraform” | Aligns with job‑specific language |
# | **Quantify impact** | e.g., “Reduced deployment time 30 % using AWS CloudFormation” | Increases relevance perception |
# | **Highlight certifications** | Emphasize AWS Certified Developer next to AWS skill | Boosts keyword density |
# | **Revise summary** | Use “Java, Spring Boot, AWS, PostgreSQL” explicitly | Directly matches key terms |
#
# ---
#
# **Bottom line:**
# You already score strongly on **experience relevance** and **education alignment**, but there's room to improve **skills match** and **keyword optimization**—the two biggest contributors to the overall score. Adjusting these sections will raise your ATS score and bring it in line with industry benchmarks, boosting your chances of landing a senior‑level engineering role.
# ---------- TextMessage (Visualizer_Agent) ----------
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
#
# # ------------------------------------------------------------------
# # 1. Data placeholders (Agent should replace with actual values)
# # ------------------------------------------------------------------
# user_scores = {
#     "total_score": 78,  # e.g., 82
#     "category_scores": {
#         "skills_match": 61,                # e.g., 62
#         "experience_relevance": 90,         # e.g., 100
#         "education_alignment": 100,         # e.g., 100
#         "format_structure": 85,              # e.g., 95
#         "keyword_optimization": 61           # e.g., 62
#     },
#     "weighted_breakdown": {
#         "skills_match_weighted": 18.3,                # e.g., 19.0
#         "experience_relevance_weighted": 22.5,          # e.g., 25.0
#         "education_alignment_weighted": 15.0,             # e.g., 15.0
#         "format_structure_weighted": 12.75,               # e.g., 14.0
#         "keyword_optimization_weighted": 9.15              # e.g., 9.0
#     }
# }
#
# # Industry benchmarks placeholders
# industry_benchmarks = {
#     "skills_match": 85,
#     "experience_relevance": 90,
#     "education_alignment": 92,
#     "keyword_optimization": 78
# }
#
# # ------------------------------------------------------------------
# # 2. Create a single figure with 3 subplots
# # ------------------------------------------------------------------
# fig = plt.figure(figsize=(15, 5))
# sns.set_style("whitegrid")
#
# # ---------------------- Bar Chart ----------------------
# ax1 = fig.add_subplot(1, 3, 1)
# categories = [
#     "skills_match",
#     "experience_relevance",
#     "education_alignment",
#     "keyword_optimization"
# ]
#
# candidate_vals = [user_scores["category_scores"][c] for c in categories]
# benchmark_vals = [industry_benchmarks[c] for c in categories]
#
# bar_width = 0.35
# x = np.arange(len(categories))
# ax1.bar(x - bar_width/2, candidate_vals, width=bar_width, label="Candidate", color="#4c72b0")
# ax1.bar(x + bar_width/2, benchmark_vals, width=bar_width, label="Industry Benchmark", color="#c44e52")
# ax1.set_xticks(x)
# ax1.set_xticklabels([c.replace('_', ' ').title() for c in categories], rotation=45, ha="right")
# ax1.set_ylabel("Score (%)")
# ax1.set_title("Candidate vs. Industry Benchmarks")
# ax1.set_ylim(0, 110)
# ax1.legend()
#
# # ---------------------- Pie Chart ----------------------
# ax2 = fig.add_subplot(1, 3, 2)
# labels = [
#     "Skills Match",
#     "Experience Relevance",
#     "Education Alignment",
#     "Format & Structure",
#     "Keyword Optimization"
# ]
# weights = [
#     user_scores["weighted_breakdown"]["skills_match_weighted"],
#     user_scores["weighted_breakdown"]["experience_relevance_weighted"],
#     user_scores["weighted_breakdown"]["education_alignment_weighted"],
#     user_scores["weighted_breakdown"]["format_structure_weighted"],
#     user_scores["weighted_breakdown"]["keyword_optimization_weighted"]
# ]
# ax2.pie(weights, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
# ax2.set_title("Weighted Score Contribution")
#
# # ---------------------- Radar Chart ----------------------
# ax3 = fig.add_subplot(1, 3, 3, polar=True)
# radar_labels = [
#     "Skills Match",
#     "Experience Relevance",
#     "Education Alignment",
#     "Format & Structure",
#     "Keyword Optimization"
# ]
# radar_vals = [
#     user_scores["category_scores"]["skills_match"],
#     user_scores["category_scores"]["experience_relevance"],
#     user_scores["category_scores"]["education_alignment"],
#     user_scores["category_scores"]["format_structure"],
#     user_scores["category_scores"]["keyword_optimization"]
# ]
# values = radar_vals + [radar_vals[0]]
# angles = np.linspace(0, 2 * np.pi, len(radar_labels), endpoint=False).tolist()
# angles += angles[:1]
# ax3.plot(angles, values, 'o-', linewidth=2, color="#1f77b4", label="Candidate")
# ax3.fill(angles, values, color="#1f77b4", alpha=0.15)
# ax3.set_thetagrids(np.degrees(angles[:-1]), radar_labels)
# ax3.set_ylim(0, 110)
# ax3.set_title("Performance Radar")
# ax3.grid(True)
#
# plt.tight_layout()
# plt.savefig("combined_charts.png", dpi=300)
# plt.close()
#
# print("Combined chart saved as combined_charts.png")
# ```
# ---------- TextMessage (Code_Executor_Agent) ----------
# Combined chart saved as combined_charts.png
#
# ---------- TextMessage (summarizer_agent) ----------
# Your overall ATS score is **78 / 100**, which is considered a **Good Fit** for the roles you’re targeting.
#
# ---
#
# ## Strengths
# - **Experience Relevance – 90 %**
#   Your 7 years of software engineering, including senior roles, align perfectly with the senior‑level expectations in the job ads.
# - **Education Alignment – 100 %**
#   A B.Tech in Computer Science meets or exceeds all educational requirements (most postings don’t specify a degree).
# - **Format & Structure – 85 %**
#   Your resume is clean, with clear sections and ATS‑friendly layout, making it easy for recruiters to scan.
# - **Certification – AWS Certified Developer**
#   Adds credibility for cloud‑based positions.
#
# ---
#
# ## Areas for Improvement
# | Category | Score | What it Means | Missing Keywords |
# |---------|------|--------------|-----------------|
# | **Skills Match – 61 %** | You’re covering core tech, but only a little over half of the job‑specific terms are present. | Add the exact terms employers are searching for. | **Java, Spring Boot, PostgreSQL, CI/CD, Terraform, GitHub Actions, Java Runtimes, Java Ecosystem, Cloud‑Native** |
# | **Keyword Optimization – 61 %** | The density of target keywords is lower than industry benchmarks. | Sprinkle these keywords naturally into your bullet points and summary. | Same list as above plus **Docker, Kubernetes, AWS CloudFormation, Git** |
#
# ---
#
# ## Next Steps
# 1. **Revise your summary**
#    • Highlight the most sought‑after stacks:
#    `“Senior Software Engineer with 7 yrs of experience in Java, Spring Boot, PostgreSQL, AWS, Docker, and Kubernetes.”`
# 2. **Add missing keywords to your experience bullets**
#    *Example:*
#    `“Designed and deployed micro‑services with Spring Boot and PostgreSQL, reducing data‑access latency by 30 %.”`
#    *Example:*
#    `“Automated CI/CD pipelines using GitHub Actions, Terraform, and AWS CloudFormation.”`
# 3. **Include a dedicated Skills section**
#    List all relevant technologies and tools, using the exact terminology from the ads (e.g., “Java Runtimes,” “Spring Boot,” “PostgreSQL,” “CI/CD”).
# 4. **Quantify impact** wherever possible (e.g., “Cut deployment time from 45 min to 12 min using Docker & Kubernetes”).
# 5. **Update certifications section** to show AWS‑related expertise prominently next to the skill name.
# 6. **Run a quick keyword check** against each job description (or use an online ATS checker) to ensure you hit all the high‑value terms.
# 7. **Proofread for consistency** – keep bullet‑point style uniform, avoid passive voice, and ensure all dates are in the same format.
#
# ---
#
# With these targeted adjustments, you can raise your ATS score by roughly **10–15 points**, moving you solidly into the **Excellent Fit** range and boosting your chances of landing an interview for senior‑level roles. Good luck!
# TaskResult(messages=[TextMessage(id='3dd7a63c-82a0-4d4b-ac19-e8adb2155c74', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 14, 11, 40, 28, 353744, tzinfo=datetime.timezone.utc), content="\n'John Doe\nEmail: john.doe@example.com\nPhone: +1 987 654 3210\n\nProfessional Summary:\nHighly motivated software engineer with 4 years of experience in backend and cloud technologies.\n\nSkills:\nPython, SQL, Java, Machine Learning, AWS, Docker, Kubernetes\n\nExperience:\nSoftware Engineer - ABC Tech (2018 - 2020)\nSenior Software Engineer - XYZ Solutions (2020 - Present)\n\nEducation:\nB.Tech Computer Science - University of Example (2014 - 2018)\n\nCertifications:\nAWS Certified Developer'\n", type='TextMessage'), TextMessage(id='ba6b2985-015a-4d74-849e-6410f18bbe33', source='json_extractor', models_usage=RequestUsage(prompt_tokens=403, completion_tokens=110), metadata={}, created_at=datetime.datetime(2025, 8, 14, 11, 40, 31, 728129, tzinfo=datetime.timezone.utc), content='{"file_type":null,"name":"John Doe","contact":{"email":"john.doe@example.com","phone":"+1 987 654 3210"},"skills":["Python","SQL","Java","Machine Learning","AWS","Docker","Kubernetes"],"experience":["Software Engineer - ABC Tech (2018 - 2020)","Senior Software Engineer - XYZ Solutions (2020 - Present)"],"education":["B.Tech Computer Science - University of Example (2014 - 2018)"],"certifications":["AWS Certified Developer"]}', type='TextMessage'), ToolCallRequestEvent(id='f6f41ae9-b2c0-4d38-84f2-e43a309464e5', source='Job_Description_Agent', models_usage=RequestUsage(prompt_tokens=462, completion_tokens=223), metadata={}, created_at=datetime.datetime(2025, 8, 14, 11, 40, 33, 194241, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='fc_2cd2c2f6-a20a-490a-9dba-40b118a53d94', arguments='{"query":"software engineer"}', name='JobFinder')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='97bbda60-95cf-4840-b5f1-2d55da7e4cda', source='Job_Description_Agent', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 8, 14, 11, 40, 40, 670419, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='[{\'role\': \'System Software Engineer - Java Runtimes, Tooling and Ecosystem\', \'company\': \'Canonical\', \'employment_type\': \'Full–time\', \'job_location\': \'India\', \'job_salary\': \'None - None\', \'job_description\': "Canonical is a leading provider of open source software and operating systems to the global enterprise and technology markets. Our platform, Ubuntu, is very widely used in breakthrough enterprise initiatives such as public cloud, data science, AI, engineering innovation, and IoT. Our customers include the world\'s leading public cloud and silicon providers, and industry leaders in many sectors. The company is a pioneer of global distributed collaboration, with 1200+ colleagues in 75+ countries and very few office-based roles. Teams meet two to four times yearly in person, in interesting locations around the world, to align on strategy and execution.\\n\\nThe company is founder-led, profitable, and growing.\\n\\nWe are hiring a System Software Engineer for Java Runtimes, tooling, and ecosystem\\n\\nWe are expanding our team focusing on the Java ecosystem. They will deliver the best possible Java runtimes and supporting tooling in Ubuntu, and enable Ubuntu users access to the wider Java ecosystem. Our goal is to enable mission-critical Java applications to be deployed and operated safely, securely and efficiently on large-scale Ubuntu estates. We are also keen to ensure that the cutting edge of Java innovation is available to Ubuntu users, to lay the foundation for future inventions and open source communities building on the JVM.\\n\\nThis is an exciting opportunity for a software engineer passionate about open source software, Java and the Java Virtual Machine, Linux system and software architecture. Come build a rewarding, meaningful career working with the best and brightest peo ...
